# %% [markdown]
# # Flight Delay Prediction
# #### CHAPTER 03: _Interpretation Challenges_
# ##### From **[Interpretable Machine Learning with Python](https://www.packtpub.com/product/interpretable-machine-learning-with-python/9781800203907)** by Serg Masís, published by Packt

# %% [markdown]
# ## The Preparations

# %% [markdown]
# ### Installing the Libraries

# %% [markdown]
# These are all already installed on Google Colab by default so install only if running elsewhere (and ***not already installed***):

# %%
# !pip install --upgrade pandas numpy scikit-learn matplotlib seaborn six tensorflow

# %% [markdown]
# Install these if running on Google Colab or ***not already installed***:

# %%
# !pip install --upgrade machine-learning-datasets
# !pip install --upgrade rulefit interpret skope-rules
# !pip install --no-deps git+https://github.com/maxfrenzel/CompressionVAE.git

# %% [markdown]
# ### Loading the Libraries

# %%
import math
import machine_learning_datasets as mldatasets
import pandas as pd
import numpy as np
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import metrics, linear_model, tree, naive_bayes, neighbors, ensemble,\
                    neural_network, svm, decomposition, manifold
from rulefit import RuleFit
import statsmodels.api as sm
from interpret.glassbox import ExplainableBoostingClassifier
from interpret import show
from interpret.perf import ROC
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import sys
#Next two lines of code only needed while CVAE 
#remains incompatible to Tensorflow 2.2+
import tensorflow.compat.v1 as tf
sys.modules['tensorflow'] = tf
from cvae import cvae
#Next two lines of code only needed while SkopedRules
#remains incompatible to Sklearn 0.23.0+
import six
sys.modules['sklearn.externals.six'] = six
from skrules import SkopeRules

# %% [markdown]
# ### Understanding and Preparing the Data

# %%
aad18_df = mldatasets.load("aa-domestic-delays-2018")
# Out:
# https://github.com/PacktPublishing/Interpretable-Machine-Learning-with-Python/raw/master/datasets/aa-domestic-delays-2018.csv.zip downloaded to /Users/serg/EXTEND/PROJECTS/InterpretableMLBook/programming/Chapter3/data/aa-domestic-delays-2018.csv.zip
# /Users/serg/EXTEND/PROJECTS/InterpretableMLBook/programming/Chapter3/data/aa-domestic-delays-2018.csv.zip uncompressed to /Users/serg/EXTEND/PROJECTS/InterpretableMLBook/programming/Chapter3/data/aa-domestic-delays-2018.csv
# 1 dataset files found in /Users/serg/EXTEND/PROJECTS/InterpretableMLBook/programming/Chapter3/data/aa-domestic-delays-2018.csv folder
# parsing /Users/serg/EXTEND/PROJECTS/InterpretableMLBook/programming/Chapter3/data/aa-domestic-delays-2018.csv/aa-domestic-delays-2018.csv

# %%
aad18_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 899527 entries, 0 to 899526
# Data columns (total 23 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   FL_NUM                899527 non-null  int64
#  1   ORIGIN                899527 non-null  object
#  2   DEST                  899527 non-null  object
#  3   PLANNED_DEP_DATETIME  899527 non-null  object
#  4   CRS_DEP_TIME          899527 non-null  int64
#  5   DEP_TIME              899527 non-null  float64
#  6   DEP_DELAY             899527 non-null  float64
#  7   DEP_AFPH              899527 non-null  float64
#  8   DEP_RFPH              899527 non-null  float64
#  9   TAXI_OUT              899527 non-null  float64
#  10  WHEELS_OFF            899527 non-null  float64
#  11  CRS_ELAPSED_TIME      899527 non-null  float64
#  12  PCT_ELAPSED_TIME      899527 non-null  float64
#  13  DISTANCE              899527 non-null  float64
#  14  CRS_ARR_TIME          899527 non-null  int64
#  15  ARR_AFPH              899527 non-null  float64
#  16  ARR_RFPH              899527 non-null  float64
#  17  ARR_DELAY             899527 non-null  float64
#  18  CARRIER_DELAY         899527 non-null  float64
#  19  WEATHER_DELAY         899527 non-null  float64
#  20  NAS_DELAY             899527 non-null  float64
#  21  SECURITY_DELAY        899527 non-null  float64
#  22  LATE_AIRCRAFT_DELAY   899527 non-null  float64
# dtypes: float64(17), int64(3), object(3)
# memory usage: 157.8+ MB

# %% [markdown]
# #### Data Preparation

# %%
aad18_df['PLANNED_DEP_DATETIME'] = pd.to_datetime(aad18_df['PLANNED_DEP_DATETIME'])

# %%
aad18_df['DEP_MONTH'] = aad18_df['PLANNED_DEP_DATETIME'].dt.month
aad18_df['DEP_DOW'] = aad18_df['PLANNED_DEP_DATETIME'].dt.dayofweek

# %%
aad18_df = aad18_df.drop(['PLANNED_DEP_DATETIME'], axis=1)

# %%
#Create list with 10 hubs
hubs = ['CLT', 'ORD', 'DFW', 'LAX', 'MIA', 'JFK', 'LGA', 'PHL', 'PHX', 'DCA']
#Boolean series for if ORIGIN or DEST are hubs
is_origin_hub = aad18_df['ORIGIN'].isin(hubs)
is_dest_hub = aad18_df['DEST'].isin(hubs)
#Use boolean series to set ORIGIN_HUB and DEST_HUB
aad18_df['ORIGIN_HUB'] = 0
aad18_df.loc[is_origin_hub, 'ORIGIN_HUB'] = 1
aad18_df['DEST_HUB'] = 0
aad18_df.loc[is_dest_hub, 'DEST_HUB'] = 1
#Delete columns with codes
aad18_df = aad18_df.drop(['FL_NUM', 'ORIGIN', 'DEST'], axis=1)

# %%
aad18_df.loc[aad18_df['ARR_DELAY'] > 15, ['ARR_DELAY','CARRIER_DELAY']].head(10)
# Out:
#     ARR_DELAY  CARRIER_DELAY
# 8       168.0          136.0
# 16       20.0            5.0
# 18      242.0          242.0
# 19       62.0           62.0
# 22       19.0           19.0
# 26       26.0            0.0
# 29       77.0           77.0
# 32       19.0           19.0
# 33       18.0            1.0
# 40       36.0           16.0

# %%
aad18_df = aad18_df.drop(['ARR_DELAY'], axis=1)

# %%
rand = 9
y = aad18_df['CARRIER_DELAY']
X = aad18_df.drop(['CARRIER_DELAY'], axis=1).copy()
X_train, X_test, y_train_reg, y_test_reg = train_test_split(X, y, test_size=0.15, random_state=rand)
y_train_class = y_train_reg.apply(lambda x: 1 if x > 15 else 0)
y_test_class = y_test_reg.apply(lambda x: 1 if x > 15 else 0)

# %%
corr = aad18_df.corr()
abs(corr['CARRIER_DELAY']).sort_values(ascending=False)
# Out:
# CARRIER_DELAY          1.000000
# DEP_DELAY              0.703935
# ARR_RFPH               0.101742
# LATE_AIRCRAFT_DELAY    0.083166
# DEP_RFPH               0.058659
# ARR_AFPH               0.035135
# DEP_TIME               0.030941
# NAS_DELAY              0.026792
# WHEELS_OFF             0.026787
# TAXI_OUT               0.024635
# PCT_ELAPSED_TIME       0.020980
# CRS_DEP_TIME           0.016032
# ORIGIN_HUB             0.015334
# DEST_HUB               0.013932
# DISTANCE               0.010680
# DEP_MONTH              0.009728
# CRS_ELAPSED_TIME       0.008801
# DEP_DOW                0.007043
# CRS_ARR_TIME           0.007029
# DEP_AFPH               0.006053
# WEATHER_DELAY          0.003002
# SECURITY_DELAY         0.000460
# Name: CARRIER_DELAY, dtype: float64

# %% [markdown]
# ## Reviewing Traditional Model Interpretation Methods

# %% [markdown]
# ### Predicting Minutes Delayed with Various Regression Methods

# %% [markdown]
# #### Training and Evaluating the Regression Models

# %%
reg_models = {
        #Generalized Linear Models (GLMs)
        'linear':{'model': linear_model.LinearRegression()}, 
        'linear_poly':{'model': make_pipeline(PolynomialFeatures(degree=2),
                              linear_model.LinearRegression(fit_intercept=False)) },
        'linear_interact':{'model': make_pipeline(PolynomialFeatures(interaction_only=True),
                              linear_model.LinearRegression(fit_intercept=False)) },
        'ridge':{'model': linear_model.RidgeCV(alphas=[1e-3, 1e-2, 1e-1, 1]) }, 
        #Trees  
        'decision_tree':{'model': tree.DecisionTreeRegressor(max_depth=7, random_state=rand)},
        #RuleFit
        'rulefit':{'model': RuleFit(max_rules=150, rfmode='regress', random_state=rand)}, 
        #Nearest Neighbors
        'knn':{'model': neighbors.KNeighborsRegressor(n_neighbors=7)}, 
        #Ensemble Methods
        'random_forest':{'model':ensemble.RandomForestRegressor(max_depth=7, random_state=rand)}, 
        #Neural Networks
        'mlp':{'model':neural_network.MLPRegressor(hidden_layer_sizes=(21,), max_iter=500, 
                                                   early_stopping=True, random_state=rand)}
    }

# %%
for model_name in reg_models.keys():
    if model_name != 'rulefit':
        fitted_model = reg_models[model_name]['model'].fit(X_train, y_train_reg)
    else:
        fitted_model = reg_models[model_name]['model'].fit(X_train.values, y_train_reg.values, X_test.columns)
    y_train_pred = fitted_model.predict(X_train.values)
    y_test_pred = fitted_model.predict(X_test.values)
    reg_models[model_name]['fitted'] = fitted_model
    reg_models[model_name]['preds'] = y_test_pred
    reg_models[model_name]['RMSE_train'] = math.sqrt(metrics.mean_squared_error(y_train_reg, y_train_pred))
    reg_models[model_name]['RMSE_test'] = math.sqrt(metrics.mean_squared_error(y_test_reg, y_test_pred))
    reg_models[model_name]['R2_test'] = metrics.r2_score(y_test_reg, y_test_pred)

# %%
reg_metrics = pd.DataFrame.from_dict(reg_models, 'index')[['RMSE_train', 'RMSE_test', 'R2_test']]
reg_metrics.sort_values(by='RMSE_test').style.\
    background_gradient(cmap='viridis', low=1, high=0.3, subset=['RMSE_train', 'RMSE_test']).\
    background_gradient(cmap='plasma', low=0.3, high=1, subset=['R2_test'])
# Out:
# <style  type="text/css" >
#     #T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row0_col0 {
#             background-color:  #26818e;
#             color:  #000000;
#         }    #T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row0_col1 {
#             background-color:  #26818e;
#             color:  #000000;
#         }    #T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row0_col2 {
#             background-color:  #da5a6a;
#             color:  #000000;
#         }    #T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row1_col0 {
#             background-color:  #1fa187;
#             color:  #000000;
#         }    #T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row1_col1 {
#             background-color:  #2ab07f;
#             color:  #000000;
#         }    #T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row1_col2 {
#             background-color:  #b52f8c;
#             color:  #f1f1f1;
#         }    #T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row2_col0 {
#             background-color:  #31b57b;
#             color:  #000000;
#         }    #T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row2_col1 {
#             background-color:  #31b57b;
#             color:  #000000;
#         }    #T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row2_col2 {
#             background-color:  #b02991;
#             color:  #f1f1f1;
#         }    #T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row3_col0 {
#             background-color:  #37b878;
#             color:  #000000;
#         }    #T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row3_col1 {
#             background-color:  #37b878;
#             color:  #000000;
#         }    #T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row3_col2 {
#             background-color:  #ab2494;
#             color:  #f1f1f1;
#         }    #T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row4_col0 {
#             background-color:  #3aba76;
#             color:  #000000;
#         }    #T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row4_col1 {
#             background-color:  #56c667;
#             color:  #000000;
#         }    #T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row4_col2 {
#             background-color:  #9410a2;
#             color:  #f1f1f1;
#         }    #T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row5_col0 {
#             background-color:  #69cd5b;
#             color:  #000000;
#         }    #T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row5_col1 {
#             background-color:  #67cc5c;
#             color:  #000000;
#         }    #T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row5_col2 {
#             background-color:  #8606a6;
#             color:  #f1f1f1;
#         }    #T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row6_col0 {
#             background-color:  #75d054;
#             color:  #000000;
#         }    #T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row6_col1 {
#             background-color:  #73d056;
#             color:  #000000;
#         }    #T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row6_col2 {
#             background-color:  #7b02a8;
#             color:  #f1f1f1;
#         }    #T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row7_col0 {
#             background-color:  #56c667;
#             color:  #000000;
#         }    #T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row7_col1 {
#             background-color:  #a5db36;
#             color:  #000000;
#         }    #T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row7_col2 {
#             background-color:  #5002a2;
#             color:  #f1f1f1;
#         }    #T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row8_col0 {
#             background-color:  #a8db34;
#             color:  #000000;
#         }    #T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row8_col1 {
#             background-color:  #a8db34;
#             color:  #000000;
#         }    #T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row8_col2 {
#             background-color:  #4e02a2;
#             color:  #f1f1f1;
#         }</style><table id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >RMSE_train</th>        <th class="col_heading level0 col1" >RMSE_test</th>        <th class="col_heading level0 col2" >R2_test</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55level0_row0" class="row_heading level0 row0" >mlp</th>
#                         <td id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row0_col0" class="data row0 col0" >3.243516</td>
#                         <td id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row0_col1" class="data row0 col1" >3.308597</td>
#                         <td id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row0_col2" class="data row0 col2" >0.987025</td>
#             </tr>
#             <tr>
#                         <th id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55level0_row1" class="row_heading level0 row1" >random_forest</th>
#                         <td id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row1_col0" class="data row1 col0" >5.143267</td>
#                         <td id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row1_col1" class="data row1 col1" >6.088249</td>
#                         <td id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row1_col2" class="data row1 col2" >0.956065</td>
#             </tr>
#             <tr>
#                         <th id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55level0_row2" class="row_heading level0 row2" >linear_poly</th>
#                         <td id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row2_col0" class="data row2 col0" >6.213987</td>
#                         <td id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row2_col1" class="data row2 col1" >6.339854</td>
#                         <td id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row2_col2" class="data row2 col2" >0.952359</td>
#             </tr>
#             <tr>
#                         <th id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55level0_row3" class="row_heading level0 row3" >linear_interact</th>
#                         <td id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row3_col0" class="data row3 col0" >6.454305</td>
#                         <td id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row3_col1" class="data row3 col1" >6.562285</td>
#                         <td id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row3_col2" class="data row3 col2" >0.948957</td>
#             </tr>
#             <tr>
#                         <th id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55level0_row4" class="row_heading level0 row4" >decision_tree</th>
#                         <td id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row4_col0" class="data row4 col0" >6.542924</td>
#                         <td id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row4_col1" class="data row4 col1" >7.456335</td>
#                         <td id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row4_col2" class="data row4 col2" >0.934102</td>
#             </tr>
#             <tr>
#                         <th id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55level0_row5" class="row_heading level0 row5" >linear</th>
#                         <td id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row5_col0" class="data row5 col0" >7.819643</td>
#                         <td id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row5_col1" class="data row5 col1" >7.882875</td>
#                         <td id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row5_col2" class="data row5 col2" >0.926347</td>
#             </tr>
#             <tr>
#                         <th id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55level0_row6" class="row_heading level0 row6" >ridge</th>
#                         <td id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row6_col0" class="data row6 col0" >8.122859</td>
#                         <td id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row6_col1" class="data row6 col1" >8.168530</td>
#                         <td id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row6_col2" class="data row6 col2" >0.920912</td>
#             </tr>
#             <tr>
#                         <th id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55level0_row7" class="row_heading level0 row7" >knn</th>
#                         <td id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row7_col0" class="data row7 col0" >7.360098</td>
#                         <td id="T_15eb50da_eccd_11ea_b2ef_88e9fe79da55row7_col1" class="data row7 col1" >9.259422</td>

# %% [markdown]
# ### Classifying Flights as Delayed or Not Delayed with Various Classification Methods

# %% [markdown]
# #### Training and Evaluating the Classification Models

# %%
class_models = {
        #Generalized Linear Models (GLMs)
        'logistic':{'model': linear_model.LogisticRegression()}, 
        'ridge':{'model': linear_model.RidgeClassifierCV(cv=5, alphas=[1e-3, 1e-2, 1e-1, 1],\
                                                         class_weight='balanced')},  
        #Tree
        'decision_tree':{'model': tree.DecisionTreeClassifier(max_depth=7, random_state=rand)},
        #Nearest Neighbors
        'knn':{'model': neighbors.KNeighborsClassifier(n_neighbors=7)}, 
        #Naive Bayes
        'naive_bayes':{'model': naive_bayes.GaussianNB()},
        #Ensemble Methods
        'gradient_boosting':{'model':ensemble.GradientBoostingClassifier(n_estimators=210)},
        'random_forest':{'model':ensemble.RandomForestClassifier(max_depth=11,\
                                                                 class_weight='balanced', random_state=rand)},
        #Neural Networks
        'mlp':{'model':make_pipeline(StandardScaler(),\
                                     neural_network.MLPClassifier(hidden_layer_sizes=(7,), max_iter=500,\
                                                   early_stopping=True, random_state=rand))}
    }

# %%
print(y_train_class[y_train_class==1].shape[0] / y_train_class.shape[0])
# Out:
# 0.061283264255549

# %%
for model_name in class_models.keys():
    fitted_model = class_models[model_name]['model'].fit(X_train, y_train_class)
    y_train_pred = fitted_model.predict(X_train.values)
    if model_name == 'ridge':
        y_test_pred = fitted_model.predict(X_test.values) 
    else:
        y_test_prob = fitted_model.predict_proba(X_test.values)[:,1]
        y_test_pred = np.where(y_test_prob > 0.5, 1, 0)
    class_models[model_name]['fitted'] = fitted_model
    class_models[model_name]['probs'] = y_test_prob
    class_models[model_name]['preds'] = y_test_pred
    class_models[model_name]['Accuracy_train'] = metrics.accuracy_score(y_train_class, y_train_pred)
    class_models[model_name]['Accuracy_test'] = metrics.accuracy_score(y_test_class, y_test_pred)
    class_models[model_name]['Recall_train'] = metrics.recall_score(y_train_class, y_train_pred)
    class_models[model_name]['Recall_test'] = metrics.recall_score(y_test_class, y_test_pred)
    if model_name != 'ridge':
        class_models[model_name]['ROC_AUC_test'] = metrics.roc_auc_score(y_test_class, y_test_prob)
    else:
        class_models[model_name]['ROC_AUC_test'] = 0
    class_models[model_name]['F1_test'] = metrics.f1_score(y_test_class, y_test_pred)
    class_models[model_name]['MCC_test'] = metrics.matthews_corrcoef(y_test_class, y_test_pred)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
class_metrics = pd.DataFrame.from_dict(class_models, 'index')[['Accuracy_train', 'Accuracy_test',\
                                                               'Recall_train', 'Recall_test',\
                                                               'ROC_AUC_test', 'F1_test', 'MCC_test']]
class_metrics.sort_values(by='ROC_AUC_test', ascending=False).style.\
    background_gradient(cmap='plasma', low=0.3, high=1, subset=['Accuracy_train', 'Accuracy_test']).\
    background_gradient(cmap='viridis', low=1, high=0.3, subset=['Recall_train', 'Recall_test',\
                                                                 'ROC_AUC_test', 'F1_test', 'MCC_test'])
# Out:
# <style  type="text/css" >
#     #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row0_col0 {
#             background-color:  #da5a6a;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row0_col1 {
#             background-color:  #da5a6a;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row0_col2 {
#             background-color:  #a2da37;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row0_col3 {
#             background-color:  #a8db34;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row0_col4 {
#             background-color:  #a8db34;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row0_col5 {
#             background-color:  #a8db34;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row0_col6 {
#             background-color:  #a8db34;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row1_col0 {
#             background-color:  #d45270;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row1_col1 {
#             background-color:  #d45270;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row1_col2 {
#             background-color:  #7fd34e;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row1_col3 {
#             background-color:  #81d34d;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row1_col4 {
#             background-color:  #a8db34;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row1_col5 {
#             background-color:  #8ed645;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row1_col6 {
#             background-color:  #8ed645;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row2_col0 {
#             background-color:  #9d189d;
#             color:  #f1f1f1;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row2_col1 {
#             background-color:  #9a169f;
#             color:  #f1f1f1;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row2_col2 {
#             background-color:  #a8db34;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row2_col3 {
#             background-color:  #a8db34;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row2_col4 {
#             background-color:  #a8db34;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row2_col5 {
#             background-color:  #35b779;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row2_col6 {
#             background-color:  #3dbc74;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row3_col0 {
#             background-color:  #cc4977;
#             color:  #f1f1f1;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row3_col1 {
#             background-color:  #cc4778;
#             color:  #f1f1f1;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row3_col2 {
#             background-color:  #70cf57;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row3_col3 {
#             background-color:  #70cf57;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row3_col4 {
#             background-color:  #a8db34;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row3_col5 {
#             background-color:  #73d056;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row3_col6 {
#             background-color:  #73d056;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row4_col0 {
#             background-color:  #c43e7f;
#             color:  #f1f1f1;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row4_col1 {
#             background-color:  #c43e7f;
#             color:  #f1f1f1;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row4_col2 {
#             background-color:  #3bbb75;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row4_col3 {
#             background-color:  #3dbc74;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row4_col4 {
#             background-color:  #9dd93b;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row4_col5 {
#             background-color:  #52c569;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row4_col6 {
#             background-color:  #54c568;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row5_col0 {
#             background-color:  #c23c81;
#             color:  #f1f1f1;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row5_col1 {
#             background-color:  #ba3388;
#             color:  #f1f1f1;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row5_col2 {
#             background-color:  #3aba76;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row5_col3 {
#             background-color:  #2ab07f;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row5_col4 {
#             background-color:  #98d83e;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row5_col5 {
#             background-color:  #38b977;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row5_col6 {
#             background-color:  #38b977;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row6_col0 {
#             background-color:  #8606a6;
#             color:  #f1f1f1;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row6_col1 {
#             background-color:  #8405a7;
#             color:  #f1f1f1;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row6_col2 {
#             background-color:  #26818e;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row6_col3 {
#             background-color:  #26818e;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row6_col4 {
#             background-color:  #73d056;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row6_col5 {
#             background-color:  #26818e;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row6_col6 {
#             background-color:  #26818e;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row7_col0 {
#             background-color:  #4e02a2;
#             color:  #f1f1f1;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row7_col1 {
#             background-color:  #4e02a2;
#             color:  #f1f1f1;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row7_col2 {
#             background-color:  #56c667;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row7_col3 {
#             background-color:  #58c765;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row7_col4 {
#             background-color:  #26818e;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row7_col5 {
#             background-color:  #1f988b;
#             color:  #000000;
#         }    #T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55row7_col6 {
#             background-color:  #1e9c89;
#             color:  #000000;
#         }</style><table id="T_4b359b2c_eccf_11ea_b2ef_88e9fe79da55" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy_train</th>        <th class="col_heading level0 col1" >Accuracy_test</th>        <th class="col_heading level0 col2" >Recall_train</th>        <th class="col_heading level0 col3" >Recall_test</th>        <th class="col_heading level0 col4" >ROC_AUC_test</th>        <th class="col_heading level0 col5" >F1_test</th>        <th class="col_heading level0 col6"

# %%
plt.figure(figsize = (12,12))
plt.tick_params(axis = 'both', which = 'major', labelsize = 12)
fpr, tpr, _ = metrics.roc_curve(y_test_class, class_models['naive_bayes']['probs'])
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % class_models['naive_bayes']['ROC_AUC_test'])
plt.plot([0, 1], [0, 1], 'k--')  # coin toss line
plt.xlabel('False Positive Rate', fontsize = 14)
plt.ylabel('True Positive Rate', fontsize = 14)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.legend(loc="lower right")

# %% [markdown]
# ### Visualizing Delayed Flights with Dimensionality Reduction Methods

# %%
X_train_abbrev = X_train.iloc[:,[0, 1, 2, 4, 8, 9, 11, 17, 20]]
X_test_abbrev = X_test.iloc[:,[0, 1, 2, 4, 8, 9, 11, 17, 20]]
np.random.seed(rand)
sample_size = 0.1
sample_idx = np.random.choice(X_test.shape[0],\
                              math.ceil(X_test.shape[0]*sample_size), replace=False)

dimred_methods = {
        #Decomposition
        'pca':{'method': decomposition.PCA(n_components=3, random_state=rand)},  
        #Manifold Learning
        't-sne':{'method': manifold.TSNE(n_components=3, random_state=rand)},
        #Variational Autoencoders
        'vae':{'method': cvae.CompressionVAE(X_train_abbrev.values,\
                                             dim_latent=3, tb_logging=False)}, 
    }
# Out:
# Total amount of data:  688137
# Input feature dimension:  9
# Calculating normalisation factors.
# Normalisation factors calculated.
# Total amount of data:  76460
# Creating model.
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/cvae/lib/model_iaf.py:22: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model created.
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/cvae/lib/model_iaf.py:241: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Setting up loss.
# Loss set up.
# Setting up session.
# Session set up.
# Trying to restore saved checkpoints from /Users/serg/EXTEND/PROJECTS/InterpretableMLBook/programming/Chapter3/temp ... No checkpoint found.
# No model found to restore. Initialising new model.

# %%
for method_name in dimred_methods.keys():
    if method_name != 'vae':
        lowdim_data = dimred_methods[method_name]['method'].\
                        fit_transform(X_test_abbrev.values[sample_idx])
    else:
        fitted_model = dimred_methods[method_name]['method'].train(num_steps=1000)
        lowdim_data = fitted_model.embed(X_test_abbrev.values[sample_idx])
        dimred_methods[method_name]['fitted'] = fitted_model
    dimred_methods[method_name]['lowdim'] = lowdim_data
# Out:
# Starting queues.
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/cvae/cvae.py:464: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:`tf.train.start_queue_runners()` was called when no queue runners were defined. You can safely remove the call to this deprecated function.
# Reader threads started.
# step 0; epoch 0.00 - loss = 7.382, test_loss = 9.677, lr = 0.00100, (0.161 sec/step)
# Storing checkpoint to /Users/serg/EXTEND/PROJECTS/InterpretableMLBook/programming/Chapter3/temp ...WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'b' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'b' has type str, but expected one of: int, long, bool
#  Done.
# step 50; epoch 0.00 - loss = 5.286, test_loss = 8.113, lr = 0.00100, (0.123 sec/step)
# step 100; epoch 0.01 - loss = 4.619, test_loss = 7.155, lr = 0.00100, (0.149 sec/step)
# step 150; epoch 0.01 - loss = 4.166, test_loss = 6.871, lr = 0.00100, (0.142 sec/step)
# step 200; epoch 0.02 - loss = 4.299, test_loss = 6.690, lr = 0.00100, (0.140 sec/step)
# step 250; epoch 0.02 - loss = 4.642, test_loss = 6.647, lr = 0.00100, (0.148 sec/step)
# step 300; epoch 0.03 - loss = 4.157, test_loss = 6.585, lr = 0.00100, (0.147 sec/step)
# step 350; epoch 0.03 - loss = 4.173, test_loss = 6.564, lr = 0.00100, (0.145 sec/step)
# step 400; epoch 0.04 - loss = 3.935, test_loss = 6.521, lr = 0.00100, (0.152 sec/step)
# step 450; epoch 0.04 - loss = 10.228, test_loss = 6.516, lr = 0.00100, (0.148 sec/step)
# step 500; epoch 0.05 - loss = 4.016, test_loss = 6.491, lr = 0.00100, (0.153 sec/step)
# step 550; epoch 0.05 - loss = 5.147, test_loss = 6.489, lr = 0.00100, (0.148 sec/step)
# step 600; epoch 0.06 - loss = 3.814, test_loss = 6.503, lr = 0.00100, (0.150 sec/step)
# step 650; epoch 0.06 - loss = 4.514, test_loss = 6.482, lr = 0.00100, (0.145 sec/step)
# step 700; epoch 0.07 - loss = 3.978, test_loss = 6.477, lr = 0.00100, (0.136 sec/step)
# step 750; epoch 0.07 - loss = 3.722, test_loss = 6.481, lr = 0.00100, (0.134 sec/step)
# step 800; epoch 0.07 - loss = 7.441, test_loss = 6.473, lr = 0.00100, (0.130 sec/step)
# step 850; epoch 0.08 - loss = 3.745, test_loss = 6.470, lr = 0.00100, (0.136 sec/step)
# step 900; epoch 0.08 - loss = 3.679, test_loss = 6.476, lr = 0.00100, (0.130 sec/step)
# step 950; epoch 0.09 - loss = 5.024, test_loss = 6.471, lr = 0.00100, (0.130 sec/step)
# Reached training step limit of 1000 steps. Stopping.
# Storing checkpoint to /Users/serg/EXTEND/PROJECTS/InterpretableMLBook/programming/Chapter3/temp ...WARNING:tensorflow:Issue encountered when serializing variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'b' has type str, but expected one of: int, long, bool
# WARNING:tensorflow:Issue encountered when serializing trainable_variables.
# Type is unsupported, or the types of the items don't match field type in CollectionDef. Note this is a warning and probably safe to ignore.
# 'b' has type str, but expected one of: int, long, bool
#  Done.

# %%
y_names = {0:'Not Delayed', 1:'Delayed'}

# %%
mldatasets.plot_3dim_decomposition(dimred_methods['pca']['lowdim'],\
                        y_test_class.values[sample_idx], y_names)

# %%
mldatasets.plot_3dim_decomposition(dimred_methods['t-sne']['lowdim'],\
                        y_test_class.values[sample_idx], y_names)

# %%
mldatasets.plot_3dim_decomposition(dimred_methods['vae']['lowdim'],\
                        y_test_class.values[sample_idx], y_names)

# %%
y_test_class_samp = y_test_class.values[sample_idx]
y_test_pred_samp = class_models['ridge']['preds'][sample_idx]
error_vector, error_labels = mldatasets.encode_classification_error_vector(y_test_class_samp, y_test_pred_samp)

# %%
mldatasets.plot_3dim_decomposition(dimred_methods['pca']['lowdim'],\
                        error_vector, error_labels)

# %%
mldatasets.plot_3dim_decomposition(dimred_methods['t-sne']['lowdim'],\
                        error_vector, error_labels)

# %%
mldatasets.plot_3dim_decomposition(dimred_methods['vae']['lowdim'],\
                        error_vector, error_labels)

# %% [markdown]
# ## Studying Intrinsically interpretable (White-box) models

# %% [markdown]
# ### Generalized Linear Models (GLMs)

# %% [markdown]
# #### Linear Regression

# %%
coefs_lm = reg_models['linear']['fitted'].coef_
intercept_lm = reg_models['linear']['fitted'].intercept_
print('coefficients:\t%s' % coefs_lm)
print('intercept:\t%s' % intercept_lm)
# Out:
# coefficients:	[ 4.54984539e-03 -5.25067742e-03  8.94125541e-01 -1.52961053e-02
#  -4.69623002e-01  1.25277815e-01 -6.46744472e-04 -1.26240049e-02
#   4.50112895e+01  6.76385421e-04 -3.69920254e-04  5.47855860e-04
#   3.73866548e-01 -9.06364154e-01 -6.74052666e-01 -9.17411191e-01
#  -9.29843952e-01 -3.96621856e-02 -1.79666480e-02 -1.02912927e+00
#  -3.94934854e-01]
# intercept:	-37.86177932752714

# %%
print('ŷ = %0.2f + %0.4fX₁ + %0.4fX₂ + %0.3fX₃ + ...' %\
      (intercept_lm, coefs_lm[0], coefs_lm[1], coefs_lm[2]))
# Out:
# ŷ = -37.86 + 0.0045X₁ + -0.0053X₂ + 0.894X₃ + ...

# %%
coef_df = pd.DataFrame({'feature':X_train.columns.values.tolist(),\
                        'coef': coefs_lm})
print(coef_df)
# Out:
#                 feature       coef
# 0          CRS_DEP_TIME   0.004550
# 1              DEP_TIME  -0.005251
# 2             DEP_DELAY   0.894126
# 3              DEP_AFPH  -0.015296
# 4              DEP_RFPH  -0.469623
# 5              TAXI_OUT   0.125278
# 6            WHEELS_OFF  -0.000647
# 7      CRS_ELAPSED_TIME  -0.012624
# 8      PCT_ELAPSED_TIME  45.011289
# 9              DISTANCE   0.000676
# 10         CRS_ARR_TIME  -0.000370
# 11             ARR_AFPH   0.000548
# 12             ARR_RFPH   0.373867
# 13        WEATHER_DELAY  -0.906364
# 14            NAS_DELAY  -0.674053
# 15       SECURITY_DELAY  -0.917411
# 16  LATE_AIRCRAFT_DELAY  -0.929844
# 17            DEP_MONTH  -0.039662
# 18              DEP_DOW  -0.017967
# 19           ORIGIN_HUB  -1.029129
# 20             DEST_HUB  -0.394935

# %%
linreg_mdl = sm.OLS(y_train_reg, sm.add_constant(X_train))
linreg_mdl = linreg_mdl.fit()
linreg_mdl.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          CARRIER_DELAY   R-squared:                       0.921
# Model:                            OLS   Adj. R-squared:                  0.921
# Method:                 Least Squares   F-statistic:                 4.251e+05
# Date:                Wed, 02 Sep 2020   Prob (F-statistic):               0.00
# Time:                        13:32:20   Log-Likelihood:            -2.6574e+06
# No. Observations:              764597   AIC:                         5.315e+06
# Df Residuals:                  764575   BIC:                         5.315e+06
# Df Model:                          21
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                 -37.8618      0.125   -301.763      0.000     -38.108     -37.616
# CRS_DEP_TIME            0.0045   7.24e-05     62.872      0.000       0.004       0.005
# DEP_TIME               -0.0053   9.19e-05    -57.116      0.000      -0.005      -0.005
# DEP_DELAY               0.8941      0.000   2951.056      0.000       0.894       0.895
# DEP_AFPH               -0.0153      0.000    -47.725      0.000      -0.016      -0.015
# DEP_RFPH               -0.4696      0.017    -27.353      0.000      -0.503      -0.436
# TAXI_OUT                0.1253      0.001    104.120      0.000       0.123       0.128
# WHEELS_OFF             -0.0006    6.7e-05     -9.646      0.000      -0.001      -0.001
# CRS_ELAPSED_TIME       -0.0126      0.001    -19.132      0.000      -0.014      -0.011
# PCT_ELAPSED_TIME       45.0113      0.117    384.073      0.000      44.782      45.241
# DISTANCE                0.0007   8.02e-05      8.429      0.000       0.001       0.001
# CRS_ARR_TIME           -0.0004   2.18e-05    -16.939      0.000      -0.000      -0.000
# ARR_AFPH                0.0005      0.000      1.651      0.099      -0.000       0.001
# ARR_RFPH                0.3739      0.013     28.386      0.000       0.348       0.400
# WEATHER_DELAY          -0.9064      0.001   -995.366      0.000      -0.908      -0.905
# NAS_DELAY              -0.6741      0.001   -829.129      0.000      -0.676      -0.672
# SECURITY_DELAY         -0.9174      0.005   -167.857      0.000      -0.928      -0.907
# LATE_AIRCRAFT_DELAY    -0.9298      0.001  -1827.018      0.000      -0.931      -0.929
# DEP_MONTH              -0.0397      0.003    -15.019      0.000      -0.045      -0.034
# DEP_DOW                -0.0180      0.004     -4.005      0.000      -0.027      -0.009
# ORIGIN_HUB             -1.0291      0.027    -38.589      0.000      -1.081      -0.977
# DEST_HUB               -0.3949      0.026    -15.041      0.000      -0.446      -0.343
# ==============================================================================
# Omnibus:                   211121.387   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         24359701.834
# Skew:                           0.098   Prob(JB):                         0.00
# Kurtosis:                      30.651   Cond. No.                     5.69e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.69e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
summary_df = linreg_mdl.summary2().tables[1]
summary_df = summary_df.drop(['const']).reset_index().rename(columns={'index':'feature'})
summary_df['t_abs'] = abs(summary_df['t'])
summary_df.sort_values(by='t_abs', ascending=False).style.\
    background_gradient(cmap='plasma_r', low=0, high=0.1, subset=['P>|t|']).\
    background_gradient(cmap='plasma_r', low=0, high=0.1, subset=['t_abs'])
# Out:
# <style  type="text/css" >
#     #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row0_col4 {
#             background-color:  #f0f921;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row0_col7 {
#             background-color:  #3e049c;
#             color:  #f1f1f1;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row1_col4 {
#             background-color:  #f0f921;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row1_col7 {
#             background-color:  #bb3488;
#             color:  #f1f1f1;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row2_col4 {
#             background-color:  #f0f921;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row2_col7 {
#             background-color:  #f1814d;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row3_col4 {
#             background-color:  #f0f921;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row3_col7 {
#             background-color:  #f79342;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row4_col4 {
#             background-color:  #f0f921;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row4_col7 {
#             background-color:  #fdc627;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row5_col4 {
#             background-color:  #f0f921;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row5_col7 {
#             background-color:  #f7e225;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row6_col4 {
#             background-color:  #f0f921;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row6_col7 {
#             background-color:  #f5eb27;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row7_col4 {
#             background-color:  #f0f921;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row7_col7 {
#             background-color:  #f2f227;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row8_col4 {
#             background-color:  #f0f921;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row8_col7 {
#             background-color:  #f2f227;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row9_col4 {
#             background-color:  #f0f921;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row9_col7 {
#             background-color:  #f1f426;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row10_col4 {
#             background-color:  #f0f921;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row10_col7 {
#             background-color:  #f1f525;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row11_col4 {
#             background-color:  #f0f921;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row11_col7 {
#             background-color:  #f1f525;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row12_col4 {
#             background-color:  #f0f921;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row12_col7 {
#             background-color:  #f1f525;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row13_col4 {
#             background-color:  #f0f921;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row13_col7 {
#             background-color:  #f0f724;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row14_col4 {
#             background-color:  #f0f921;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row14_col7 {
#             background-color:  #f0f724;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row15_col4 {
#             background-color:  #f0f921;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row15_col7 {
#             background-color:  #f0f724;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row16_col4 {
#             background-color:  #f0f921;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row16_col7 {
#             background-color:  #f0f724;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row17_col4 {
#             background-color:  #f0f921;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row17_col7 {
#             background-color:  #f0f921;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row18_col4 {
#             background-color:  #f0f921;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row18_col7 {
#             background-color:  #f0f921;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row19_col4 {
#             background-color:  #f0f921;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row19_col7 {
#             background-color:  #f0f921;
#             color:  #000000;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row20_col4 {
#             background-color:  #3e049c;
#             color:  #f1f1f1;
#         }    #T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row20_col7 {
#             background-color:  #f0f921;
#             color:  #000000;
#         }</style><table id="T_15d22446_ed4c_11ea_b2ef_88e9fe79da55" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >feature</th>        <th class="col_heading level0 col1" >Coef.</th>        <th class="col_heading level0 col2" >Std.Err.</th>        <th class="col_heading level0 col3" >t</th>        <th class="col_heading level0 col4" >P>|t|</th>        <th class="col_heading level0 col5" >[0.025</th>        <th class="col_heading level0 col6" >0.975]</th>        <th class="col_heading level0 col7" >t_abs</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_15d22446_ed4c_11ea_b2ef_88e9fe79da55level0_row0" class="row_heading level0 row0" >2</th>
#                         <td id="T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row0_col0" class="data row0 col0" >DEP_DELAY</td>
#                         <td id="T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row0_col1" class="data row0 col1" >0.894126</td>
#                         <td id="T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row0_col2" class="data row0 col2" >0.000303</td>
#                         <td id="T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row0_col3" class="data row0 col3" >2951.055978</td>
#                         <td id="T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row0_col4" class="data row0 col4" >0.000000</td>
#                         <td id="T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row0_col5" class="data row0 col5" >0.893532</td>
#                         <td id="T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row0_col6" class="data row0 col6" >0.894719</td>
#                         <td id="T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row0_col7" class="data row0 col7" >2951.055978</td>
#             </tr>
#             <tr>
#                         <th id="T_15d22446_ed4c_11ea_b2ef_88e9fe79da55level0_row1" class="row_heading level0 row1" >16</th>
#                         <td id="T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row1_col0" class="data row1 col0" >LATE_AIRCRAFT_DELAY</td>
#                         <td id="T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row1_col1" class="data row1 col1" >-0.929844</td>
#                         <td id="T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row1_col2" class="data row1 col2" >0.000509</td>
#                         <td id="T_15d22446_ed4c_11ea_b2ef_88e9fe79da55row1_col3" class="data row1 col3" >-1827.018082</td>
#                         <td id

# %% [markdown]
# #### Ridge Regression

# %%
coefs_ridge = reg_models['ridge']['fitted'].coef_
coef_ridge_df = pd.DataFrame({'feature':X_train.columns.values.tolist(),\
                        'coef_linear': coefs_lm,\
                        'coef_ridge': coefs_ridge})
coef_ridge_df.style.\
    background_gradient(cmap='viridis_r', low=0.3, high=0.2, axis=1)
# Out:
# <style  type="text/css" >
#     #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row0_col1 {
#             background-color:  #7ad151;
#             color:  #000000;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row0_col2 {
#             background-color:  #472f7d;
#             color:  #f1f1f1;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row1_col1 {
#             background-color:  #7ad151;
#             color:  #000000;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row1_col2 {
#             background-color:  #472f7d;
#             color:  #f1f1f1;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row2_col1 {
#             background-color:  #472f7d;
#             color:  #f1f1f1;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row2_col2 {
#             background-color:  #7ad151;
#             color:  #000000;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row3_col1 {
#             background-color:  #472f7d;
#             color:  #f1f1f1;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row3_col2 {
#             background-color:  #7ad151;
#             color:  #000000;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row4_col1 {
#             background-color:  #472f7d;
#             color:  #f1f1f1;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row4_col2 {
#             background-color:  #7ad151;
#             color:  #000000;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row5_col1 {
#             background-color:  #472f7d;
#             color:  #f1f1f1;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row5_col2 {
#             background-color:  #7ad151;
#             color:  #000000;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row6_col1 {
#             background-color:  #7ad151;
#             color:  #000000;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row6_col2 {
#             background-color:  #472f7d;
#             color:  #f1f1f1;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row7_col1 {
#             background-color:  #472f7d;
#             color:  #f1f1f1;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row7_col2 {
#             background-color:  #7ad151;
#             color:  #000000;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row8_col1 {
#             background-color:  #472f7d;
#             color:  #f1f1f1;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row8_col2 {
#             background-color:  #7ad151;
#             color:  #000000;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row9_col1 {
#             background-color:  #472f7d;
#             color:  #f1f1f1;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row9_col2 {
#             background-color:  #7ad151;
#             color:  #000000;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row10_col1 {
#             background-color:  #7ad151;
#             color:  #000000;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row10_col2 {
#             background-color:  #472f7d;
#             color:  #f1f1f1;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row11_col1 {
#             background-color:  #472f7d;
#             color:  #f1f1f1;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row11_col2 {
#             background-color:  #7ad151;
#             color:  #000000;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row12_col1 {
#             background-color:  #7ad151;
#             color:  #000000;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row12_col2 {
#             background-color:  #472f7d;
#             color:  #f1f1f1;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row13_col1 {
#             background-color:  #472f7d;
#             color:  #f1f1f1;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row13_col2 {
#             background-color:  #7ad151;
#             color:  #000000;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row14_col1 {
#             background-color:  #7ad151;
#             color:  #000000;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row14_col2 {
#             background-color:  #472f7d;
#             color:  #f1f1f1;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row15_col1 {
#             background-color:  #7ad151;
#             color:  #000000;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row15_col2 {
#             background-color:  #472f7d;
#             color:  #f1f1f1;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row16_col1 {
#             background-color:  #7ad151;
#             color:  #000000;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row16_col2 {
#             background-color:  #472f7d;
#             color:  #f1f1f1;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row17_col1 {
#             background-color:  #472f7d;
#             color:  #f1f1f1;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row17_col2 {
#             background-color:  #7ad151;
#             color:  #000000;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row18_col1 {
#             background-color:  #472f7d;
#             color:  #f1f1f1;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row18_col2 {
#             background-color:  #7ad151;
#             color:  #000000;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row19_col1 {
#             background-color:  #472f7d;
#             color:  #f1f1f1;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row19_col2 {
#             background-color:  #7ad151;
#             color:  #000000;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row20_col1 {
#             background-color:  #7ad151;
#             color:  #000000;
#         }    #T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row20_col2 {
#             background-color:  #472f7d;
#             color:  #f1f1f1;
#         }</style><table id="T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >feature</th>        <th class="col_heading level0 col1" >coef_linear</th>        <th class="col_heading level0 col2" >coef_ridge</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row0_col0" class="data row0 col0" >CRS_DEP_TIME</td>
#                         <td id="T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row0_col1" class="data row0 col1" >0.004550</td>
#                         <td id="T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row0_col2" class="data row0 col2" >0.005373</td>
#             </tr>
#             <tr>
#                         <th id="T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row1_col0" class="data row1 col0" >DEP_TIME</td>
#                         <td id="T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row1_col1" class="data row1 col1" >-0.005251</td>
#                         <td id="T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row1_col2" class="data row1 col2" >-0.003627</td>
#             </tr>
#             <tr>
#                         <th id="T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row2_col0" class="data row2 col0" >DEP_DELAY</td>
#                         <td id="T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row2_col1" class="data row2 col1" >0.894126</td>
#                         <td id="T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row2_col2" class="data row2 col2" >0.894013</td>
#             </tr>
#             <tr>
#                         <th id="T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row3_col0" class="data row3 col0" >DEP_AFPH</td>
#                         <td id="T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row3_col1" class="data row3 col1" >-0.015296</td>
#                         <td id="T_76dd34aa_ecd5_11ea_b2ef_88e9fe79da55row3_col2" class="data row3 col2" >-0.015322

# %%
num_alphas = 100
alphas = np.logspace(0, 13, num_alphas)
alphas_coefs = []
for alpha in alphas:
    ridge = linear_model.Ridge(alpha=alpha).fit(X_train, y_train_reg)
    alphas_coefs.append(np.concatenate((ridge.coef_[:8],ridge.coef_[9:])))

# %%
plt.figure(figsize = (12,8))
plt.gca().invert_xaxis()
plt.tick_params(axis = 'both', which = 'major', labelsize = 12)
plt.plot(alphas, alphas_coefs)
plt.xscale("log")
plt.xlabel('Alpha', fontsize = 14)
plt.ylabel('Ridge coefficients', fontsize = 14)
plt.grid()
plt.show()

# %% [markdown]
# #### Polynomial Regression

# %%
print(reg_models['linear_poly']['fitted'].get_params()['linearregression'].coef_.shape[0])
# Out:
# 253

# %%
print(reg_models['linear_interact']['fitted'].get_params()['linearregression'].coef_.shape[0])
# Out:
# 232

# %% [markdown]
# #### Logistic Regression

# %%
coefs_log = class_models['logistic']['fitted'].coef_
intercept_log = class_models['logistic']['fitted'].intercept_
print('coefficients:\t%s' % coefs_log)
print('intercept:\t%s' % intercept_log)
# Out:
# coefficients:	[[-1.23151812e-03  2.93774704e-04  1.61338034e-01  1.77493349e-03
#   -2.15915422e-03 -4.35450242e-03  1.27984682e-04 -5.17720785e-02
#   -1.76310069e-03  5.61580071e-03 -2.53698323e-04 -6.79027014e-03
#   -2.74571712e-03 -1.53557236e-01 -1.21227428e-01 -5.99414743e-03
#   -1.65188544e-01 -1.31214181e-02 -5.33132240e-03  4.78845293e-04
#   -2.07097380e-03]]
# intercept:	[-0.00230901]

# %%
stdv = np.std(X_train, 0)
abs(coefs_log.reshape(21,) * stdv).sort_values(ascending=False)
# Out:
# DEP_DELAY              7.141532
# CRS_ELAPSED_TIME       4.109450
# LATE_AIRCRAFT_DELAY    4.082085
# DISTANCE               3.647053
# NAS_DELAY              1.670519
# WEATHER_DELAY          1.604633
# CRS_DEP_TIME           0.617492
# ARR_AFPH               0.240126
# DEP_TIME               0.151267
# CRS_ARR_TIME           0.133986
# WHEELS_OFF             0.066116
# DEP_AFPH               0.062930
# DEP_MONTH              0.044779
# TAXI_OUT               0.042975
# DEP_DOW                0.010654
# SECURITY_DELAY         0.009825
# ARR_RFPH               0.001981
# DEP_RFPH               0.001220
# DEST_HUB               0.001007
# ORIGIN_HUB             0.000233
# PCT_ELAPSED_TIME       0.000186
# dtype: float64

# %% [markdown]
# ### Decision Trees

# %% [markdown]
# #### CART Decision Trees

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 1, figsize = (16,8), dpi=600)
tree.plot_tree(class_models['decision_tree']['fitted'],\
               feature_names=X_train.columns.values.tolist(), filled = True, max_depth=2)
fig.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   after removing the cwd from sys.path.

# %%
text_tree = tree.export_text(class_models['decision_tree']['fitted'],\
               feature_names=X_train.columns.values.tolist())
print(text_tree)
# Out:
# |--- DEP_DELAY <= 20.50
# |   |--- DEP_DELAY <= 15.50
# |   |   |--- class: 0
# |   |--- DEP_DELAY >  15.50
# |   |   |--- PCT_ELAPSED_TIME <= 0.99
# |   |   |   |--- PCT_ELAPSED_TIME <= 0.98
# |   |   |   |   |--- PCT_ELAPSED_TIME <= 0.96
# |   |   |   |   |   |--- CRS_ELAPSED_TIME <= 65.50
# |   |   |   |   |   |   |--- PCT_ELAPSED_TIME <= 0.94
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- PCT_ELAPSED_TIME >  0.94
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- CRS_ELAPSED_TIME >  65.50
# |   |   |   |   |   |   |--- PCT_ELAPSED_TIME <= 0.95
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- PCT_ELAPSED_TIME >  0.95
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- PCT_ELAPSED_TIME >  0.96
# |   |   |   |   |   |--- CRS_ELAPSED_TIME <= 140.50
# |   |   |   |   |   |   |--- DEP_DELAY <= 18.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- DEP_DELAY >  18.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- CRS_ELAPSED_TIME >  140.50
# |   |   |   |   |   |   |--- DEP_DELAY <= 19.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- DEP_DELAY >  19.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- PCT_ELAPSED_TIME >  0.98
# |   |   |   |   |--- DEP_DELAY <= 18.50
# |   |   |   |   |   |--- DISTANCE <= 326.50
# |   |   |   |   |   |   |--- LATE_AIRCRAFT_DELAY <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- LATE_AIRCRAFT_DELAY >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- DISTANCE >  326.50
# |   |   |   |   |   |   |--- DEP_DELAY <= 17.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- DEP_DELAY >  17.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- DEP_DELAY >  18.50
# |   |   |   |   |   |--- LATE_AIRCRAFT_DELAY <= 1.50
# |   |   |   |   |   |   |--- DISTANCE <= 1358.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- DISTANCE >  1358.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- LATE_AIRCRAFT_DELAY >  1.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |--- PCT_ELAPSED_TIME >  0.99
# |   |   |   |--- LATE_AIRCRAFT_DELAY <= 1.50
# |   |   |   |   |--- WEATHER_DELAY <= 2.00
# |   |   |   |   |   |--- NAS_DELAY <= 17.50
# |   |   |   |   |   |   |--- PCT_ELAPSED_TIME <= 1.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- PCT_ELAPSED_TIME >  1.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- NAS_DELAY >  17.50
# |   |   |   |   |   |   |--- PCT_ELAPSED_TIME <= 1.09
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- PCT_ELAPSED_TIME >  1.09
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- WEATHER_DELAY >  2.00
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- LATE_AIRCRAFT_DELAY >  1.50
# |   |   |   |   |--- LATE_AIRCRAFT_DELAY <= 3.50
# |   |   |   |   |   |--- DEP_DELAY <= 18.50
# |   |   |   |   |   |   |--- DISTANCE <= 153.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- DISTANCE >  153.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- DEP_DELAY >  18.50
# |   |   |   |   |   |   |--- WEATHER_DELAY <= 2.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- WEATHER_DELAY >  2.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- LATE_AIRCRAFT_DELAY >  3.50
# |   |   |   |   |   |--- LATE_AIRCRAFT_DELAY <= 4.50
# |   |   |   |   |   |   |--- DEP_DELAY <= 19.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- DEP_DELAY >  19.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- LATE_AIRCRAFT_DELAY >  4.50
# |   |   |   |   |   |   |--- class: 0
# |--- DEP_DELAY >  20.50
# |   |--- LATE_AIRCRAFT_DELAY <= 11.50
# |   |   |--- NAS_DELAY <= 27.50
# |   |   |   |--- DEP_DELAY <= 35.50
# |   |   |   |   |--- PCT_ELAPSED_TIME <= 0.96
# |   |   |   |   |   |--- DEP_DELAY <= 28.50
# |   |   |   |   |   |   |--- PCT_ELAPSED_TIME <= 0.93
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- PCT_ELAPSED_TIME >  0.93
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- DEP_DELAY >  28.50
# |   |   |   |   |   |   |--- PCT_ELAPSED_TIME <= 0.92
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- PCT_ELAPSED_TIME >  0.92
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- PCT_ELAPSED_TIME >  0.96
# |   |   |   |   |   |--- WEATHER_DELAY <= 4.50
# |   |   |   |   |   |   |--- LATE_AIRCRAFT_DELAY <= 6.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- LATE_AIRCRAFT_DELAY >  6.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- WEATHER_DELAY >  4.50
# |   |   |   |   |   |   |--- WEATHER_DELAY <= 10.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- WEATHER_DELAY >  10.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- DEP_DELAY >  35.50
# |   |   |   |   |--- WEATHER_DELAY <= 16.50
# |   |   |   |   |   |--- DEP_DELAY <= 44.50
# |   |   |   |   |   |   |--- PCT_ELAPSED_TIME <= 0.93
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- PCT_ELAPSED_TIME >  0.93
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- DEP_DELAY >  44.50
# |   |   |   |   |   |   |--- SECURITY_DELAY <= 20.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- SECURITY_DELAY >  20.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- WEATHER_DELAY >  16.50
# |   |   |   |   |   |--- WEATHER_DELAY <= 23.50
# |   |   |   |   |   |   |--- DEP_DELAY <= 57.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- DEP_DELAY >  57.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- WEATHER_DELAY >  23.50
# |   |   |   |   |   |   |--- DEP_DELAY <= 88.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- DEP_DELAY >  88.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- NAS_DELAY >  27.50
# |   |   |   |--- PCT_ELAPSED_TIME <= 1.11
# |   |   |   |   |--- NAS_DELAY <= 31.50
# |   |   |   |   |   |--- PCT_ELAPSED_TIME <= 1.07
# |   |   |   |   |   |   |--- DEP_DELAY <= 69.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- DEP_DELAY >  69.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- PCT_ELAPSED_TIME >  1.07
# |   |   |   |   |   |   |--- WEATHER_DELAY <= 10.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- WEATHER_DELAY >  10.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- NAS_DELAY >  31.50
# |   |   |   |   |   |--- DEP_DELAY <= 471.50
# |   |   |   |   |   |   |--- CRS_ELAPSED_TIME <= 420.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- CRS_ELAPSED_TIME >  420.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- DEP_DELAY >  471.50
# |   |   |   |   |   |   |--- NAS_DELAY <= 388.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- NAS_DELAY >  388.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- PCT_ELAPSED_TIME >  1.11
# |   |   |   |   |--- NAS_DELAY <= 64.50
# |   |   |   |   |   |--- WEATHER_DELAY <= 20.50
# |   |   |   |   |   |   |--- DEP_DELAY <= 43.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- DEP_DELAY >  43.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- WEATHER_DELAY >  20.50
# |   |   |   |   |   |   |--- WHEELS_OFF <= 36.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- WHEELS_OFF >  36.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- NAS_DELAY >  64.50
# |   |   |   |   |   |--- PCT_ELAPSED_TIME <= 1.44
# |   |   |   |   |   |   |--- NAS_DELAY <= 78.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- NAS_DELAY >  78.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- PCT_ELAPSED_TIME >  1.44
# |   |   |   |   |   |   |--- NAS_DELAY <= 119.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- NAS_DELAY >  119.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |--- LATE_AIRCRAFT_DELAY >  11.50
# |   |   |--- DEP_DELAY <= 75.50
# |   |   |   |--- DEP_DELAY <= 41.50
# |   |   |   |   |--- LATE_AIRCRAFT_DELAY <= 14.50
# |   |   |   |   |   |--- DEP_DELAY <= 29.50
# |   |   |   |   |   |   |--- DEP_DELAY <= 27.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- DEP_DELAY >  27.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- DEP_DELAY >  29.50
# |   |   |   |   |   |   |--- PCT_ELAPSED_TIME <= 0.97
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- PCT_ELAPSED_TIME >  0.97
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- LATE_AIRCRAFT_DELAY >  14.50
# |   |   |   |   |   |--- LATE_AIRCRAFT_DELAY <= 20.50
# |   |   |   |   |   |   |--- DEP_DELAY <= 32.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- DEP_DELAY >  32.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- LATE_AIRCRAFT_DELAY >  20.50
# |   |   |   |   |   |   |--- DEP_DELAY <= 38.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- DEP_DELAY >  38.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- DEP_DELAY >  41.50
# |   |   |   |   |--- LATE_AIRCRAFT_DELAY <= 29.50
# |   |   |   |   |   |--- PCT_ELAPSED_TIME <= 0.94
# |   |   |   |   |   |   |--- DEP_DELAY <= 55.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- DEP_DELAY >  55.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- PCT_ELAPSED_TIME >  0.94
# |   |   |   |   |   |   |--- WEATHER_DELAY <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- WEATHER_DELAY >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- LATE_AIRCRAFT_DELAY >  29.50
# |   |   |   |   |   |--- LATE_AIRCRAFT_DELAY <= 38.50
# |   |   |   |   |   |   |--- DEP_DELAY <= 59.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- DEP_DELAY >  59.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- LATE_AIRCRAFT_DELAY >  38.50
# |   |   |   |   |   |   |--- DEP_DELAY <= 60.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- DEP_DELAY >  60.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- DEP_DELAY >  75.50
# |   |   |   |--- LATE_AIRCRAFT_DELAY <= 60.50
# |   |   |   |   |--- WEATHER_DELAY <= 0.50
# |   |   |   |   |   |--- NAS_DELAY <= 38.50
# |   |   |   |   |   |   |--- DEP_DELAY <= 88.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- DEP_DELAY >  88.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- NAS_DELAY >  38.50
# |   |   |   |   |   |   |--- TAXI_OUT <= 63.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- TAXI_OUT >  63.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- WEATHER_DELAY >  0.50
# |   |   |   |   |   |--- WEATHER_DELAY <= 18.50
# |   |   |   |   |   |   |--- LATE_AIRCRAFT_DELAY <= 31.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- LATE_AIRCRAFT_DELAY >  31.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- WEATHER_DELAY >  18.50
# |   |   |   |   |   |   |--- DEP_AFPH <= 99.64
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- DEP_AFPH >  99.64
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- LATE_AIRCRAFT_DELAY >  60.50
# |   |   |   |   |--- DEP_DELAY <= 114.50
# |   |   |   |   |   |--- LATE_AIRCRAFT_DELAY <= 71.50
# |   |   |   |   |   |   |--- DEP_DELAY <= 95.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- DEP_DELAY >  95.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- LATE_AIRCRAFT_DELAY >  71.50
# |   |   |   |   |   |   |--- DEP_DELAY <= 96.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- DEP_DELAY >  96.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- DEP_DELAY >  114.50
# |   |   |   |   |   |--- LATE_AIRCRAFT_DELAY <= 98.50
# |   |   |   |   |   |   |--- WEATHER_DELAY <= 1.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- WEATHER_DELAY >  1.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- LATE_AIRCRAFT_DELAY >  98.50
# |   |   |   |   |   |   |--- DEP_DELAY <= 171.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- DEP_DELAY >  171.50
# |   |   |   |   |   |   |   |--- class: 0

# %%
dt_imp_df = pd.DataFrame({'feature':X_train.columns.values.tolist(),\
                        'importance': class_models['decision_tree']['fitted'].feature_importances_}).\
            sort_values(by='importance', ascending=False)
dt_imp_df
# Out:
#                 feature  importance
# 2             DEP_DELAY    0.527482
# 16  LATE_AIRCRAFT_DELAY    0.199153
# 8      PCT_ELAPSED_TIME    0.105381
# 13        WEATHER_DELAY    0.101649
# 14            NAS_DELAY    0.062732
# 15       SECURITY_DELAY    0.001998
# 9              DISTANCE    0.001019
# 7      CRS_ELAPSED_TIME    0.000281
# 5              TAXI_OUT    0.000239
# 6            WHEELS_OFF    0.000035
# 3              DEP_AFPH    0.000031
# 0          CRS_DEP_TIME    0.000000
# 19           ORIGIN_HUB    0.000000
# 18              DEP_DOW    0.000000
# 17            DEP_MONTH    0.000000
# 10         CRS_ARR_TIME    0.000000
# 12             ARR_RFPH    0.000000
# 11             ARR_AFPH    0.000000
# 1              DEP_TIME    0.000000
# 4              DEP_RFPH    0.000000
# 20             DEST_HUB    0.000000

# %% [markdown]
# ### RuleFit

# %%
rulefit_df = reg_models['rulefit']['fitted'].get_rules()
rulefit_df = rulefit_df[rulefit_df.coef != 0].sort_values(by="importance", ascending=False)
rulefit_df
# Out:
#                                                   rule    type        coef  \
# 56   DEP_DELAY > 344.0 & WEATHER_DELAY <= 166.0 & L...    rule  222.054419
# 23    LATE_AIRCRAFT_DELAY <= 333.5 & DEP_DELAY > 477.5    rule  172.380029
# 16                                 LATE_AIRCRAFT_DELAY  linear   -0.386460
# 2                                            DEP_DELAY  linear    0.163546
# 67                                  DEP_DELAY > 1206.0    rule  290.051584
# ..                                                 ...     ...         ...
# 62              DEP_DELAY <= 477.5 & DEP_DELAY > 218.5    rule    0.304649
# 115  DEP_DELAY <= 490.5 & DEP_DELAY > 58.5 & LATE_A...    rule    0.120538
# 18                                             DEP_DOW  linear    0.009917
# 163             DEP_DELAY <= 136.5 & DEP_DELAY <= 48.5    rule   -0.046215
# 72              DEP_DELAY <= 48.5 & DEP_DELAY <= 534.5    rule   -0.007695
#
#       support  importance
# 56   0.001684    9.103331
# 23   0.001122    5.771707
# 16   1.000000    4.528198
# 2    1.000000    4.278776
# 67   0.000187    3.966616
# ..        ...         ...
# 62   0.006173    0.023861
# 115  0.032735    0.021449
# 18   1.000000    0.019817
# 163  0.922933    0.012325
# 72   0.921811    0.002066
#
# [82 rows x 5 columns]

# %% [markdown]
# ### Nearest Neighbors

# %% [markdown]
# #### k-Nearest Neighbors (kNN)

# %%
print(X_test.loc[721043,:])
# Out:
# CRS_DEP_TIME            655.000000
# DEP_TIME               1055.000000
# DEP_DELAY               240.000000
# DEP_AFPH                 90.800000
# DEP_RFPH                  0.890196
# TAXI_OUT                 35.000000
# WHEELS_OFF             1130.000000
# CRS_ELAPSED_TIME        259.000000
# PCT_ELAPSED_TIME          1.084942
# DISTANCE               1660.000000
# CRS_ARR_TIME            914.000000
# ARR_AFPH                 40.434783
# ARR_RFPH                  1.064073
# WEATHER_DELAY             0.000000
# NAS_DELAY                22.000000
# SECURITY_DELAY            0.000000
# LATE_AIRCRAFT_DELAY     221.000000
# DEP_MONTH                10.000000
# DEP_DOW                   4.000000
# ORIGIN_HUB                1.000000
# DEST_HUB                  0.000000
# Name: 721043, dtype: float64

# %%
print(y_test_class[721043])
# Out:
# 1

# %%
print(y_test_class[721043])
# Out:
# 1

# %%
print(class_models['knn']['preds'][X_test.index.get_loc(721043)])
# Out:
# 0

# %%
print(class_models['knn']['fitted'].kneighbors(X_test.loc[721043,:].values.reshape(1,21), 7))
# Out:
# (array([[143.3160128 , 173.90740076, 192.66705727, 211.57109221,
#         243.57211853, 259.61593993, 259.77507391]]), array([[105172, 571912,  73409,  89450,  77474, 705972, 706911]]))

# %%
print(y_train_class.iloc[[105172, 571912,  73409,  89450,  77474, 705972, 706911]])
# Out:
# 3813      0
# 229062    1
# 283316    0
# 385831    0
# 581905    1
# 726784    1
# 179364    0
# Name: CARRIER_DELAY, dtype: int64

# %%
print(class_models['knn']['fitted'].effective_metric_)
# Out:
# euclidean

# %% [markdown]
# ### Naïve Bayes

# %% [markdown]
# #### Gaussian Naïve Bayes

# %%
print(class_models['naive_bayes']['fitted'].class_prior_)
# Out:
# [0.93871674 0.06128326]

# %%
print(class_models['naive_bayes']['fitted'].sigma_)
# Out:
# [[2.50123026e+05 2.61324730e+05 9.21572605e+02 1.26123968e+03
#   2.08339528e-01 9.58074414e+01 2.62606651e+05 6.30102550e+03
#   1.13475535e-02 4.22470414e+05 2.75433641e+05 1.25314386e+03
#   3.48655340e-01 1.11234714e+02 1.91877186e+02 2.80302201e+00
#   5.06561612e+02 1.17346654e+01 3.99122491e+00 2.39015406e-01
#   2.34996222e-01]
#  [2.60629652e+05 2.96009867e+05 1.19307931e+04 1.14839167e+03
#   1.99929921e+00 1.20404927e+02 3.08568277e+05 6.29066219e+03
#   1.38936741e-02 4.10198938e+05 3.28574000e+05 1.09023147e+03
#   3.08997044e+00 7.79140423e+01 1.56184090e+02 9.12112286e-01
#   2.11279954e+03 1.02712368e+01 4.02943162e+00 1.77750796e-01
#   2.50208354e-01]]

# %%
print(class_models['naive_bayes']['fitted'].theta_)
# Out:
# [[1.30740577e+03 1.31006271e+03 5.14196506e+00 5.45864877e+01
#   1.09377996e+00 1.87120810e+01 1.33552258e+03 1.70734929e+02
#   9.71131781e-01 1.01824369e+03 1.48438931e+03 5.39873058e+01
#   1.09644787e+00 7.39971299e-01 2.85434558e+00 2.41814585e-02
#   4.14674395e+00 6.55045281e+00 2.95035528e+00 6.06800513e-01
#   6.24199571e-01]
#  [1.41305545e+03 1.48087887e+03 8.45867640e+01 6.14731036e+01
#   1.25429654e+00 1.99378321e+01 1.49409412e+03 1.72229998e+02
#   9.83974416e-01 1.04363666e+03 1.54821862e+03 4.26486417e+01
#   1.36373798e+00 4.50733082e-01 4.71991378e+00 2.11281132e-02
#   1.40744819e+01 6.73367907e+00 3.04251232e+00 7.69575517e-01
#   4.85391724e-01]]

# %% [markdown]
# ## Discovering Newer Interpretable (Glass-box) Models

# %% [markdown]
# ### Explainable Boosting Machine (EBM)

# %%
#Make new abbreviated versions of datasets
feature_samp = ['DEP_DELAY', 'LATE_AIRCRAFT_DELAY', 'PCT_ELAPSED_TIME', 'WEATHER_DELAY',\
                'NAS_DELAY', 'SECURITY_DELAY', 'DISTANCE', 'CRS_ELAPSED_TIME']
X_train_abbrev2 = X_train[feature_samp]
X_test_abbrev2 = X_test[feature_samp]
#For sampling among observations
np.random.seed(rand)
sample2_size = 0.1
sample2_idx = np.random.choice(X_train.shape[0], math.ceil(X_train.shape[0]*sample2_size), replace=False)

# %%
ebm_mdl = ExplainableBoostingClassifier()
ebm_mdl.fit(X_train_abbrev2.iloc[sample2_idx], y_train_class.iloc[sample2_idx])
# Out:
# ExplainableBoostingClassifier(binning='quantile', early_stopping_rounds=50,
#                               early_stopping_tolerance=0,
#                               feature_names=['DEP_DELAY', 'LATE_AIRCRAFT_DELAY',
#                                              'PCT_ELAPSED_TIME',
#                                              'WEATHER_DELAY', 'NAS_DELAY',
#                                              'SECURITY_DELAY', 'DISTANCE',
#                                              'CRS_ELAPSED_TIME'],
#                               feature_types=['continuous', 'continuous',
#                                              'continuous', 'continuous',
#                                              'continuous', 'continuous',
#                                              'continuous', 'continuous'],
#                               inner_bags=0, interactions=0, learning_rate=0.01,
#                               mains='all', max_bins=255, max_leaves=3,
#                               max_rounds=5000, min_samples_leaf=2, n_jobs=-2,
#                               outer_bags=16, random_state=42,
#                               validation_size=0.15)

# %%
show(ebm_mdl.explain_global())
# Out:
# <!-- http://127.0.0.1:7001/112817066832/ -->
# <iframe src="http://127.0.0.1:7001/112817066832/" width=100% height=800 frameBorder="0"></iframe>

# %%
ebm_lcl = ebm_mdl.explain_local(X_test_abbrev2.iloc[76:77],\
                                y_test_class[76:77], name='EBM')
show(ebm_lcl)
# Out:
# <!-- http://127.0.0.1:7001/113880453392/ -->
# <iframe src="http://127.0.0.1:7001/113880453392/" width=100% height=800 frameBorder="0"></iframe>

# %%
ebm_perf = ROC(ebm_mdl.predict_proba).\
                            explain_perf(X_test_abbrev2.iloc[sample_idx],\
                                         y_test_class.iloc[sample_idx], name='EBM')
show(ebm_perf)
# Out:
# <!-- http://127.0.0.1:7001/113069476368/ -->
# <iframe src="http://127.0.0.1:7001/113069476368/" width=100% height=800 frameBorder="0"></iframe>

# %% [markdown]
# ### Skoped Rules

# %%
sr_mdl = SkopeRules(n_estimators=200, precision_min=0.2, recall_min=0.01,\
                    n_jobs=-1, random_state=rand, max_depth=7,\
                    feature_names=X_train_abbrev2.columns)
sr_mdl.fit(X_train_abbrev2.iloc[sample2_idx], y_train_class.iloc[sample2_idx])
# Out:
# SkopeRules(bootstrap=False, bootstrap_features=False,
#            feature_names=Index(['DEP_DELAY', 'LATE_AIRCRAFT_DELAY', 'PCT_ELAPSED_TIME', 'WEATHER_DELAY',
#        'NAS_DELAY', 'SECURITY_DELAY', 'DISTANCE', 'CRS_ELAPSED_TIME'],
#       dtype='object'),
#            max_depth=7, max_depth_duplication=None, max_features=1.0,
#            max_samples=0.8, max_samples_features=1.0, min_samples_split=2,
#            n_estimators=200, n_jobs=-1, precision_min=0.2, random_state=9,
#            recall_min=0.01, verbose=0)

# %%
sr_y_test_prob = sr_mdl.score_top_rules(X_test_abbrev2.iloc[sample_idx])
sr_y_test_pred = np.where(sr_y_test_prob > 0.5, 1, 0)

# %%
print(len(sr_mdl.rules_))
# Out:
# 1517

# %%
print(sr_mdl.rules_[0:5])
# Out:
# [('DEP_DELAY > 39.5 and LATE_AIRCRAFT_DELAY <= 12.5 and WEATHER_DELAY <= 12.0 and NAS_DELAY <= 27.5 and SECURITY_DELAY <= 8.5', (0.959051724137931, 0.4777241009125067, 2)), ('DEP_DELAY > 39.5 and LATE_AIRCRAFT_DELAY <= 12.5 and WEATHER_DELAY <= 12.0 and NAS_DELAY <= 27.5 and SECURITY_DELAY <= 16.5', (0.9590878374516092, 0.4757740862307305, 6)), ('DEP_DELAY > 39.5 and LATE_AIRCRAFT_DELAY <= 11.5 and WEATHER_DELAY <= 12.0 and NAS_DELAY <= 27.5 and SECURITY_DELAY <= 20.5', (0.9598373709847126, 0.4728846642569354, 6)), ('DEP_DELAY > 39.5 and LATE_AIRCRAFT_DELAY <= 12.5 and WEATHER_DELAY <= 12.5 and NAS_DELAY <= 27.5 and SECURITY_DELAY <= 16.5', (0.9569012547735952, 0.4712520150456744, 2)), ('DEP_DELAY > 39.5 and LATE_AIRCRAFT_DELAY <= 11.5 and WEATHER_DELAY <= 12.0 and NAS_DELAY <= 27.5 and SECURITY_DELAY <= 19.0', (0.9589380988822661, 0.4700764303305863, 4))]

# %%
print('actual: %s, predicted: %s' % (y_test_class.iloc[76], sr_y_test_pred[76]))
# Out:
# actual: 1, predicted: 0

# %%
print(sr_mdl.decision_function(X_test_abbrev2.iloc[76:77]))
# Out:
# [18.23328729]

# %%
print('accuracy: %.3g, recall: %.3g, roc auc: %.3g, f1: %.3g, mcc: %.3g' %\
      (metrics.accuracy_score(y_test_class.iloc[sample_idx], sr_y_test_pred),\
       metrics.recall_score(y_test_class.iloc[sample_idx], sr_y_test_pred),\
       metrics.roc_auc_score(y_test_class.iloc[sample_idx], sr_y_test_prob),\
       metrics.f1_score(y_test_class.iloc[sample_idx], sr_y_test_pred),\
       metrics.matthews_corrcoef(y_test_class.iloc[sample_idx], sr_y_test_pred)))
# Out:
# accuracy: 0.961, recall: 0.981, roc auc: 0.984, f1: 0.748, mcc: 0.753
