# %%
import mldatasets
import math
import pandas as pd
import numpy as np
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn import metrics, linear_model, tree, discriminant_analysis,\
                    ensemble, neural_network, inspection
import matplotlib.pyplot as plt
from pdpbox import pdp
from pycebox.ice import ice, ice_plot

# %%
birthorder_df = mldatasets.load("personality-birthorder", prepare=True)
# Out:
# https://openpsychometrics.org/_rawdata/FBPS-ValidationData.zip downloaded to /Users/serg/EXTEND/PROJECTS/InterpretableMLBook/programming/Chapter4/data/FBPS-ValidationData.zip
# /Users/serg/EXTEND/PROJECTS/InterpretableMLBook/programming/Chapter4/data/FBPS-ValidationData.zip uncompressed to /Users/serg/EXTEND/PROJECTS/InterpretableMLBook/programming/Chapter4/data/FBPS-ValidationData
# 1 dataset files found in /Users/serg/EXTEND/PROJECTS/InterpretableMLBook/programming/Chapter4/data/FBPS-ValidationData folder
# parsing /Users/serg/EXTEND/PROJECTS/InterpretableMLBook/programming/Chapter4/data/FBPS-ValidationData/FBPS-ValidationData/FBPS-ValidationData.csv

# %%
birthorder_df.shape
# Out:
# (25813, 97)

# %%
rand = 9
y = birthorder_df['birthorder']
X = birthorder_df.drop(['birthorder'], axis=1).copy()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=rand)

# %%
class_models = {  
        #Tree
        'decision_tree':{'model': tree.\
                         DecisionTreeClassifier(max_depth=6, random_state=rand,\
                                                class_weight='balanced')},
        #Ensemble Methods
        'gradient_boosting':{'model':ensemble.\
                             GradientBoostingClassifier(n_estimators=200,\
                                                        max_depth=4, subsample=0.5,\
                                                        learning_rate=0.05)},
        'random_forest':{'model':ensemble.\
                         RandomForestClassifier(max_depth=11, n_estimators=300,\
                                                max_features='sqrt', random_state=rand)},
        #Generalized Linear Models (GLMs)
        'logistic':{'model': linear_model.\
                    LogisticRegression(multi_class='ovr', solver='lbfgs',\
                                       class_weight='balanced', max_iter=500)},
        #Discriminant Analysis
        'lda':{'model':discriminant_analysis.\
               LinearDiscriminantAnalysis(n_components=2)},
        #Neural Networks
        'mlp':{'model':make_pipeline(StandardScaler(), neural_network.\
                                     MLPClassifier(hidden_layer_sizes=(11,),\
                                                   early_stopping=True, random_state=rand,\
                                                   validation_fraction=0.25, max_iter=500))}
    }

# %%
for model_name in class_models.keys():
    fitted_model = class_models[model_name]['model'].fit(X_train, y_train) 
    y_train_pred = fitted_model.predict(X_train)
    y_test_pred = fitted_model.predict(X_test)
    class_models[model_name]['fitted'] = fitted_model
    class_models[model_name]['preds'] = y_test_pred
    class_models[model_name]['Accuracy_train'] =\
        metrics.accuracy_score(y_train, y_train_pred)
    class_models[model_name]['Accuracy_test'] =\
        metrics.accuracy_score(y_test, y_test_pred)
    class_models[model_name]['Recall_train'] =\
        metrics.recall_score(y_train, y_train_pred, average='weighted')
    class_models[model_name]['Recall_test'] =\
        metrics.recall_score(y_test, y_test_pred, average='weighted')
    class_models[model_name]['Precision_train'] =\
        metrics.precision_score(y_train, y_train_pred, average='weighted')
    class_models[model_name]['Precision_test'] =\
        metrics.precision_score(y_test, y_test_pred, average='weighted')
    class_models[model_name]['F1_test'] =\
        metrics.f1_score(y_test, y_test_pred, average='weighted')
    class_models[model_name]['MCC_test'] =\
        metrics.matthews_corrcoef(y_test, y_test_pred)

# %%
class_metrics = pd.DataFrame.\
    from_dict(class_models, 'index')[['Accuracy_train', 'Accuracy_test',\
                                      'Recall_train', 'Recall_test',\
                                      'Precision_train', 'Precision_test',\
                                      'F1_test', 'MCC_test']]
class_metrics.sort_values(by='MCC_test', ascending=False).style.\
    background_gradient(cmap='plasma', low=0.43, high=0.63,\
                        subset=['Accuracy_train', 'Accuracy_test']).\
    background_gradient(cmap='viridis', low=0.63, high=0.43,
                        subset=['Recall_train', 'Recall_test',\
                                'Precision_train', 'Precision_test',\
                                'F1_test'])
# Out:
# <style  type="text/css" >
#     #T_afa061fc_fc7c_11ea_a754_acde48001122row0_col0 {
#             background-color:  #6e00a8;
#             color:  #f1f1f1;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row0_col1 {
#             background-color:  #6e00a8;
#             color:  #f1f1f1;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row0_col2 {
#             background-color:  #34618d;
#             color:  #f1f1f1;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row0_col3 {
#             background-color:  #34618d;
#             color:  #f1f1f1;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row0_col4 {
#             background-color:  #2e6d8e;
#             color:  #f1f1f1;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row0_col5 {
#             background-color:  #35b779;
#             color:  #000000;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row0_col6 {
#             background-color:  #34618d;
#             color:  #f1f1f1;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row1_col0 {
#             background-color:  #6e00a8;
#             color:  #f1f1f1;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row1_col1 {
#             background-color:  #f1814d;
#             color:  #000000;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row1_col2 {
#             background-color:  #34618d;
#             color:  #f1f1f1;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row1_col3 {
#             background-color:  #75d054;
#             color:  #000000;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row1_col4 {
#             background-color:  #34618d;
#             color:  #f1f1f1;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row1_col5 {
#             background-color:  #75d054;
#             color:  #000000;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row1_col6 {
#             background-color:  #75d054;
#             color:  #000000;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row2_col0 {
#             background-color:  #a31e9a;
#             color:  #f1f1f1;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row2_col1 {
#             background-color:  #de6164;
#             color:  #000000;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row2_col2 {
#             background-color:  #25858e;
#             color:  #000000;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row2_col3 {
#             background-color:  #3dbc74;
#             color:  #000000;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row2_col4 {
#             background-color:  #24878e;
#             color:  #000000;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row2_col5 {
#             background-color:  #228d8d;
#             color:  #000000;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row2_col6 {
#             background-color:  #23a983;
#             color:  #000000;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row3_col0 {
#             background-color:  #7a02a8;
#             color:  #f1f1f1;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row3_col1 {
#             background-color:  #e76e5b;
#             color:  #000000;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row3_col2 {
#             background-color:  #31688e;
#             color:  #f1f1f1;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row3_col3 {
#             background-color:  #50c46a;
#             color:  #000000;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row3_col4 {
#             background-color:  #31668e;
#             color:  #f1f1f1;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row3_col5 {
#             background-color:  #238a8d;
#             color:  #000000;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row3_col6 {
#             background-color:  #2eb37c;
#             color:  #000000;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row4_col0 {
#             background-color:  #6f00a8;
#             color:  #f1f1f1;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row4_col1 {
#             background-color:  #e06363;
#             color:  #000000;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row4_col2 {
#             background-color:  #33628d;
#             color:  #f1f1f1;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row4_col3 {
#             background-color:  #40bd72;
#             color:  #000000;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row4_col4 {
#             background-color:  #34618d;
#             color:  #f1f1f1;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row4_col5 {
#             background-color:  #1fa088;
#             color:  #000000;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row4_col6 {
#             background-color:  #25ac82;
#             color:  #000000;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row5_col0 {
#             background-color:  #f1814d;
#             color:  #000000;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row5_col1 {
#             background-color:  #c6417d;
#             color:  #f1f1f1;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row5_col2 {
#             background-color:  #75d054;
#             color:  #000000;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row5_col3 {
#             background-color:  #1fa287;
#             color:  #000000;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row5_col4 {
#             background-color:  #75d054;
#             color:  #000000;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row5_col5 {
#             background-color:  #34618d;
#             color:  #f1f1f1;
#         }    #T_afa061fc_fc7c_11ea_a754_acde48001122row5_col6 {
#             background-color:  #2e6d8e;
#             color:  #f1f1f1;
#         }</style><table id="T_afa061fc_fc7c_11ea_a754_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy_train</th>        <th class="col_heading level0 col1" >Accuracy_test</th>        <th class="col_heading level0 col2" >Recall_train</th>        <th class="col_heading level0 col3" >Recall_test</th>        <th class="col_heading level0 col4" >Precision_train</th>        <th class="col_heading level0 col5" >Precision_test</th>        <th class="col_heading level0 col6" >F1_test</th>        <th class="col_heading level0 col7" >MCC_test</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_afa061fc_fc7c_11ea_a754_acde48001122level0_row0" class="row_heading level0 row0" >decision_tree</th>
#                         <td id="T_afa061fc_fc7c_11ea_a754_acde48001122row0_col0" class="data row0 col0" >0.496704</td>
#                         <td id="T_afa061fc_fc7c_11ea_a754_acde48001122row0_col1" class="data row0 col1" >0.464139</td>
#                         <td id="T_afa061fc_fc7c_11ea_a754_acde48001122row0_col2" class="data row0 col2" >0.496704</td>
#                         <td id="T_afa061fc_fc7c_11ea_a754_acde48001122row0_col3" class="data row0 col3" >0.464139</td>
#                         <td id="T_afa061fc_fc7c_11ea_a754_acde48001122row0_col4" class="data row0 col4" >0.541157</td>
#                         <td id="T_afa061fc_fc7c_11ea_a754_acde48001122row0_col5" class="data row0 col5" >0.493572</td>
#                         <td id="T_afa061fc_fc7c_11ea_a754_acde48001122row0_col6" class="data row0 col6" >0.441380</td>
#                         <td id="T_afa061fc_fc7c_11ea_a754_acde48001122row0_col7" class="data row0 col7" >0.245647</td>
#             </tr>
#             <tr>
#                         <th id="T_afa061fc_fc7c_11ea_a754_acde48001122level0_row1" class="row_heading level0 row1" >logistic</th>
#                         <td id="T_afa061fc_fc7c_11ea_a754_acde48001122row1_col0" class="data row1 col0" >0.498092</td>
#                         <td id="T_afa061fc_fc7c_11ea_a754_acde48001122row1_col1" class="data row1 col1" >0.499120</td>
#                         <td id="T_afa061fc_fc7c_11ea_a754_acde48001122row1_col2" class="data row1 col2" >0.498092</td>
#                         <td id="T_afa061fc_fc7c_11ea_a754_acde48001122row1_col3" class="data row1 col3" >0.499120</td>

# %%
print('NIR: %.4f' %\
      (y_train[y_train==1].shape[0]/y_train.shape[0]))
# Out:
# NIR: 0.4215

# %%
dt_imp_df = pd.DataFrame({\
                'name': X_train.columns,
                'dt_imp': class_models['decision_tree']['fitted'].\
                          feature_importances_})
gb_imp_df = pd.DataFrame({\
                'name': X_train.columns,
                'gb_imp': class_models['gradient_boosting']['fitted'].\
                          feature_importances_})
rf_imp_df = pd.DataFrame({\
                'name': X_train.columns,
                'rf_imp': class_models['random_forest']['fitted'].\
                         feature_importances_})

# %%
dt_rank_df = pd.DataFrame({'dt_rank':\
                           dt_imp_df['dt_imp'].\
                           rank(method='first',\
                                ascending=False).astype(int)})
gb_rank_df = pd.DataFrame({'gb_rank':\
                           gb_imp_df['gb_imp'].\
                           rank(method='first',\
                                ascending=False).astype(int)})
rf_rank_df = pd.DataFrame({'rf_rank':\
                           rf_imp_df['rf_imp'].\
                           rank(method='first',\
                                ascending=False).astype(int)})

# %%
tree_ranks_df = pd.merge(\
                    pd.merge(\
                        pd.concat((dt_imp_df, dt_rank_df), axis=1),\
                        pd.concat((gb_imp_df, gb_rank_df), axis=1),\
                        'left'),\
                    pd.concat((rf_imp_df, rf_rank_df), axis=1),\
                    'left')
tree_ranks_df['avg_rank'] = (tree_ranks_df['dt_rank'] +\
                            tree_ranks_df['gb_rank'] + \
                            tree_ranks_df['rf_rank'])/3
tree_ranks_df.sort_values(by='avg_rank')
# Out:
#                 name    dt_imp  dt_rank    gb_imp  gb_rank    rf_imp  rf_rank  \
# 28            birthn  0.851533        1  0.370814        1  0.196067        1
# 81        testelapse  0.013708        3  0.037204        2  0.027307        2
# 0                 Q1  0.025340        2  0.022593        6  0.016135        6
# 26               age  0.006679        7  0.027452        5  0.025065        3
# 80       introelapse  0.005056        9  0.030397        4  0.022142        5
# ..               ...       ...      ...       ...      ...       ...      ...
# 89        country_GB  0.000000       90  0.001094       90  0.002023       91
# 94     source_google  0.000000       95  0.000772       95  0.003204       82
# 91        country_NZ  0.000000       92  0.001003       91  0.000690       93
# 90        country_IE  0.000000       91  0.000861       93  0.000577       95
# 83  gender_undefined  0.000000       87  0.000554       96  0.000241       96
#
#      avg_rank
# 28   1.000000
# 81   2.333333
# 0    4.666667
# 26   5.000000
# 80   6.000000
# ..        ...
# 89  90.333333
# 94  90.666667
# 91  92.000000
# 90  93.000000
# 83  93.000000
#
# [96 rows x 8 columns]

# %%
print(class_models['logistic']['fitted'].coef_.shape)
# Out:
# (3, 96)

# %%
stdv = np.std(X_train, 0)
lr_imp_df = pd.DataFrame({\
                'name': X_train.columns,\
                'first_coef_norm':\
                          class_models['logistic']['fitted'].coef_[0] * stdv,\
                'middle_coef_norm':\
                          class_models['logistic']['fitted'].coef_[1] * stdv,\
                'last_coef_norm':\
                          class_models['logistic']['fitted'].coef_[2] * stdv}).\
            reset_index(drop=True)

# %%
class_priors = class_models['lda']['fitted'].priors_
print(class_priors)
# Out:
# [0.42147566 0.23701862 0.34150572]

# %%
lr_imp_df['coef_weighted_avg'] = (abs(lr_imp_df['first_coef_norm']) * class_priors[0]) +\
                                 (abs(lr_imp_df['middle_coef_norm']) * class_priors[1]) +\
                                 (abs(lr_imp_df['last_coef_norm']) * class_priors[2])

# %%
lr_imp_df.\
    sort_values(by='coef_weighted_avg', ascending=False).style.\
    background_gradient(cmap='viridis', low=-0.1, high=0.1,\
                        subset=['first_coef_norm',\
                                'middle_coef_norm', 'last_coef_norm'])
# Out:
# <style  type="text/css" >
#     #T_afc58ef0_fc7c_11ea_a754_acde48001122row0_col1 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row0_col2 {
#             background-color:  #bddf26;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row0_col3 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row1_col1 {
#             background-color:  #bddf26;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row1_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row1_col3 {
#             background-color:  #24878e;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row2_col1 {
#             background-color:  #93d741;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row2_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row2_col3 {
#             background-color:  #2fb47c;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row3_col1 {
#             background-color:  #7cd250;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row3_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row3_col3 {
#             background-color:  #54c568;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row4_col1 {
#             background-color:  #23a983;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row4_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row4_col3 {
#             background-color:  #95d840;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row5_col1 {
#             background-color:  #70cf57;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row5_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row5_col3 {
#             background-color:  #3fbc73;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row6_col1 {
#             background-color:  #5ac864;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row6_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row6_col3 {
#             background-color:  #9dd93b;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row7_col1 {
#             background-color:  #4cc26c;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row7_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row7_col3 {
#             background-color:  #bade28;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row8_col1 {
#             background-color:  #28ae80;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row8_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row8_col3 {
#             background-color:  #bddf26;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row9_col1 {
#             background-color:  #27ad81;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row9_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row9_col3 {
#             background-color:  #90d743;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row10_col1 {
#             background-color:  #65cb5e;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row10_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row10_col3 {
#             background-color:  #7ad151;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row11_col1 {
#             background-color:  #69cd5b;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row11_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row11_col3 {
#             background-color:  #58c765;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row12_col1 {
#             background-color:  #69cd5b;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row12_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row12_col3 {
#             background-color:  #6ece58;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row13_col1 {
#             background-color:  #69cd5b;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row13_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row13_col3 {
#             background-color:  #42be71;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row14_col1 {
#             background-color:  #67cc5c;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row14_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row14_col3 {
#             background-color:  #70cf57;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row15_col1 {
#             background-color:  #63cb5f;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row15_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row15_col3 {
#             background-color:  #42be71;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row16_col1 {
#             background-color:  #29af7f;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row16_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row16_col3 {
#             background-color:  #9dd93b;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row17_col1 {
#             background-color:  #60ca60;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row17_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row17_col3 {
#             background-color:  #67cc5c;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row18_col1 {
#             background-color:  #5ec962;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row18_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row18_col3 {
#             background-color:  #52c569;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row19_col1 {
#             background-color:  #2cb17e;
#             color:  #000000;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row19_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afc58ef0_fc7c_11ea_a754_acde48001122row19_col3 {
#             background-color:  #addc30;

# %%
class_models['lda']['fitted'].coef_.shape
# Out:
# (3, 96)

# %%
lda_imp_df = pd.DataFrame({\
                'name': X_train.columns,\
                'first_coef_norm':\
                          class_models['lda']['fitted'].coef_[0] * stdv,\
                'middle_coef_norm':\
                          class_models['lda']['fitted'].coef_[1] * stdv,\
                'last_coef_norm':\
                          class_models['lda']['fitted'].coef_[2] * stdv}).\
            reset_index(drop=True)

# %%
lda_imp_df['coef_weighted_avg'] = (abs(lda_imp_df['first_coef_norm']) * class_priors[0]) +\
                                 (abs(lda_imp_df['middle_coef_norm']) * class_priors[1]) +\
                                 (abs(lda_imp_df['last_coef_norm']) * class_priors[2])

# %%
lda_imp_df.\
    sort_values(by='coef_weighted_avg', ascending=False).style.\
    background_gradient(cmap='viridis', low=-0.1, high=0.1,\
                        subset=['first_coef_norm',\
                                'middle_coef_norm', 'last_coef_norm'])
# Out:
# <style  type="text/css" >
#     #T_afdb3fca_fc7c_11ea_a754_acde48001122row0_col1 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row0_col2 {
#             background-color:  #bddf26;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row0_col3 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row1_col1 {
#             background-color:  #bddf26;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row1_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row1_col3 {
#             background-color:  #23888e;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row2_col1 {
#             background-color:  #86d549;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row2_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row2_col3 {
#             background-color:  #28ae80;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row3_col1 {
#             background-color:  #20a386;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row3_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row3_col3 {
#             background-color:  #bddf26;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row4_col1 {
#             background-color:  #69cd5b;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row4_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row4_col3 {
#             background-color:  #3fbc73;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row5_col1 {
#             background-color:  #35b779;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row5_col2 {
#             background-color:  #450457;
#             color:  #f1f1f1;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row5_col3 {
#             background-color:  #2db27d;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row6_col1 {
#             background-color:  #65cb5e;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row6_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row6_col3 {
#             background-color:  #31b57b;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row7_col1 {
#             background-color:  #21a685;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row7_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row7_col3 {
#             background-color:  #7fd34e;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row8_col1 {
#             background-color:  #22a785;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row8_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row8_col3 {
#             background-color:  #70cf57;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row9_col1 {
#             background-color:  #22a884;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row9_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row9_col3 {
#             background-color:  #73d056;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row10_col1 {
#             background-color:  #5ec962;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row10_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row10_col3 {
#             background-color:  #31b57b;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row11_col1 {
#             background-color:  #5cc863;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row11_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row11_col3 {
#             background-color:  #3aba76;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row12_col1 {
#             background-color:  #5ac864;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row12_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row12_col3 {
#             background-color:  #4ac16d;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row13_col1 {
#             background-color:  #4ec36b;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row13_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row13_col3 {
#             background-color:  #75d054;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row14_col1 {
#             background-color:  #54c568;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row14_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row14_col3 {
#             background-color:  #69cd5b;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row15_col1 {
#             background-color:  #25ab82;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row15_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row15_col3 {
#             background-color:  #73d056;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row16_col1 {
#             background-color:  #50c46a;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row16_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row16_col3 {
#             background-color:  #6ece58;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row17_col1 {
#             background-color:  #58c765;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row17_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row17_col3 {
#             background-color:  #5cc863;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row18_col1 {
#             background-color:  #25ac82;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row18_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row18_col3 {
#             background-color:  #65cb5e;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row19_col1 {
#             background-color:  #25ac82;
#             color:  #000000;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row19_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_afdb3fca_fc7c_11ea_a754_acde48001122row19_col3 {
#             background-color:  #8bd646;

# %%
print(class_models['mlp']['fitted'][1].coefs_[0].shape)
print(class_models['mlp']['fitted'][1].coefs_[1].shape)
# Out:
# (96, 11)
# (11, 3)

# %%
for model_name in class_models.keys():
    fitted_model = class_models[model_name]['fitted']
    permutation_imp = inspection.permutation_importance(\
                        fitted_model, X_test, y_test, n_jobs=-1,\
                        scoring='accuracy', n_repeats=8,\
                        random_state=rand)
    class_models[model_name]['importances_mean'] =\
                        permutation_imp.importances_mean

# %%
perm_imp_df = pd.DataFrame({
                'name': X_train.columns,\
                'dt_imp': class_models['decision_tree']['importances_mean'],\
                'gb_imp': class_models['gradient_boosting']['importances_mean'],\
                'rf_imp': class_models['random_forest']['importances_mean'],\
                'log_imp': class_models['logistic']['importances_mean'],\
                'lda_imp': class_models['lda']['importances_mean'],\
                'mlp_imp': class_models['mlp']['importances_mean']}).\
            reset_index(drop=True)

# %%
perm_imp_df['avg_imp'] = (perm_imp_df['dt_imp'] + perm_imp_df['gb_imp'] +\
                         perm_imp_df['rf_imp'] + perm_imp_df['log_imp'] +\
                         perm_imp_df['lda_imp'] + perm_imp_df['mlp_imp'])/6

# %%
perm_imp_sorted_df = perm_imp_df.round(5).\
    sort_values(by='avg_imp', ascending=False)
perm_imp_sorted_df.style.\
    background_gradient(cmap='viridis_r', low=0, high=0.2,\
                        subset=['dt_imp', 'gb_imp', 'rf_imp',\
                                'log_imp', 'lda_imp', 'mlp_imp'])
# Out:
# <style  type="text/css" >
#     #T_2c63f852_fc7d_11ea_a754_acde48001122row0_col1 {
#             background-color:  #443983;
#             color:  #f1f1f1;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row0_col2 {
#             background-color:  #443983;
#             color:  #f1f1f1;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row0_col3 {
#             background-color:  #443983;
#             color:  #f1f1f1;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row0_col4 {
#             background-color:  #443983;
#             color:  #f1f1f1;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row0_col5 {
#             background-color:  #443983;
#             color:  #f1f1f1;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row0_col6 {
#             background-color:  #443983;
#             color:  #f1f1f1;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row1_col1 {
#             background-color:  #d5e21a;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row1_col2 {
#             background-color:  #dfe318;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row1_col3 {
#             background-color:  #eae51a;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row1_col4 {
#             background-color:  #c5e021;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row1_col5 {
#             background-color:  #aadc32;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row1_col6 {
#             background-color:  #cde11d;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row2_col1 {
#             background-color:  #f1e51d;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row2_col2 {
#             background-color:  #f8e621;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row2_col3 {
#             background-color:  #e5e419;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row2_col4 {
#             background-color:  #ece51b;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row2_col5 {
#             background-color:  #dae319;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row2_col6 {
#             background-color:  #e7e419;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row3_col1 {
#             background-color:  #f4e61e;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row3_col2 {
#             background-color:  #f6e620;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row3_col3 {
#             background-color:  #eae51a;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row3_col4 {
#             background-color:  #eae51a;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row3_col5 {
#             background-color:  #dfe318;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row3_col6 {
#             background-color:  #e7e419;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row4_col1 {
#             background-color:  #f6e620;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row4_col2 {
#             background-color:  #f1e51d;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row4_col3 {
#             background-color:  #e2e418;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row4_col4 {
#             background-color:  #eae51a;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row4_col5 {
#             background-color:  #efe51c;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row4_col6 {
#             background-color:  #e7e419;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row5_col1 {
#             background-color:  #f1e51d;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row5_col2 {
#             background-color:  #efe51c;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row5_col3 {
#             background-color:  #d2e21b;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row5_col4 {
#             background-color:  #f4e61e;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row5_col5 {
#             background-color:  #f8e621;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row5_col6 {
#             background-color:  #ece51b;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row6_col1 {
#             background-color:  #f6e620;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row6_col2 {
#             background-color:  #f1e51d;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row6_col3 {
#             background-color:  #e7e419;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row6_col4 {
#             background-color:  #efe51c;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row6_col5 {
#             background-color:  #f4e61e;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row6_col6 {
#             background-color:  #e7e419;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row7_col1 {
#             background-color:  #efe51c;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row7_col2 {
#             background-color:  #ece51b;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row7_col3 {
#             background-color:  #efe51c;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row7_col4 {
#             background-color:  #f6e620;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row7_col5 {
#             background-color:  #efe51c;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row7_col6 {
#             background-color:  #ece51b;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row8_col1 {
#             background-color:  #f6e620;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row8_col2 {
#             background-color:  #f1e51d;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row8_col3 {
#             background-color:  #e2e418;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row8_col4 {
#             background-color:  #f1e51d;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row8_col5 {
#             background-color:  #efe51c;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row8_col6 {
#             background-color:  #efe51c;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row9_col1 {
#             background-color:  #eae51a;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row9_col2 {
#             background-color:  #ece51b;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row9_col3 {
#             background-color:  #f8e621;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row9_col4 {
#             background-color:  #f8e621;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row9_col5 {
#             background-color:  #f1e51d;
#             color:  #000000;
#         }    #T_2c63f852_fc7d_11ea_a754_acde48001122row9_col6 {
#             background-color:  #ece51b;
#             color:  #000000;

# %%
pd.DataFrame.\
    from_dict(class_models, 'index')[['Accuracy_test']] -\
    perm_imp_sorted_df.iloc[0,1:7].to_numpy().reshape((6,1))
# Out:
#                   Accuracy_test
# decision_tree          0.325639
# gradient_boosting      0.386162
# random_forest          0.409015
# logistic                0.38326
# lda                    0.408777
# mlp                    0.385114

# %%
feature_names = ['birthn', 'Q1', 'Q13', 'age']
feature_labels = ['# of Births', 'Question #1',\
                  'Question #13', 'Age']

# %%
for i in range(len(feature_names)):
    pdp_feat_df = pdp.pdp_isolate(\
        model=class_models['gradient_boosting']['fitted'],\
        dataset=pd.concat((X_test, y_test), axis=1),\
        model_features=X_test.columns,\
        feature=feature_names[i]
    )
    fig, axes = pdp.pdp_plot(
        pdp_isolate_out=pdp_feat_df, center=True,\
        x_quantile=True, ncols=3, plot_lines=True,\
        frac_to_plot=100, figsize=(15,6),\
        feature_name=feature_labels[i]
    )

# %%
birthorder_abbrev_df = birthorder_df[['age', 'birthorder']]
birthorder_abbrev_df.set_index(pd.cut(\
                                  birthorder_abbrev_df['age'],\
                                  [12, 16, 18, 20, 22, 26, 30,\
                                   36, 46, 88]), inplace=True)
agegroup_birthorder_counts_s = birthorder_abbrev_df.\
                            groupby([birthorder_abbrev_df.index,\
                                     'birthorder']).size()
agegroup_counts_s = birthorder_abbrev_df.groupby(\
                                            birthorder_abbrev_df.index)\
                                            ['birthorder'].count()
agegroup_pct_birthorder_s = agegroup_birthorder_counts_s.div(\
                                                    agegroup_counts_s,\
                                                     axis=0,level=0)
agegroup_pct_birthorder_s.unstack().plot.bar(stacked=True,\
                                         figsize=(15,8))

# %%
pdp_birthn_Q1_df = pdp.pdp_interact(
    model=class_models['random_forest']['fitted'],\
    dataset=pd.concat((X_test, y_test), axis=1),\
    model_features=X_test.columns, features=['birthn','Q1'],\
    n_jobs=-1
)
fig, axes = pdp.pdp_interact_plot(
    pdp_interact_out=pdp_birthn_Q1_df,\
    plot_type='grid', x_quantile=True,\
    ncols=2, figsize=(15,15),\
    feature_names=['# of Births','Question #1']
)

# %%
pdp_age_testelapse_df = pdp.pdp_interact(
    model=class_models['random_forest']['fitted'],\
    dataset=pd.concat((X_test, y_test), axis=1),\
    model_features=X_test.columns, features=['age','testelapse'],\
    n_jobs=-1
)
fig, axes = pdp.pdp_interact_plot(
    pdp_interact_out=pdp_age_testelapse_df,\
    plot_type='contour', x_quantile=True,\
    ncols=2, figsize=(15,15),\
    feature_names=['Age','Time taking test (minutes)']
)

# %%
np.random.seed(rand)
sample_size = 0.1
sample_idx = np.random.choice(\
                    X_test.shape[0],\
                    math.ceil(X_test.shape[0]*sample_size),\
                    replace=False)
X_test_samp = X_test.iloc[sample_idx,:]

# %%
def predict_prob_first_born(test_df):
    return class_models['random_forest']['fitted'].\
                                predict_proba(test_df)[:,0]
def predict_prob_middle_child(test_df):
    return class_models['random_forest']['fitted'].\
                                predict_proba(test_df)[:,1]
def predict_prob_last_born(test_df):
    return class_models['random_forest']['fitted'].\
                                predict_proba(test_df)[:,2]

# %%
legend_key = {0:'N/A', 1:'Disagree', 2:'Somewhat Disagree',
              3:'Neutral', 4:'Somewhat Agree', 5:'Agree'}

# %%
mldatasets.plot_data_vs_ice(predict_prob_first_born,\
                            'Probability of Firstborn',\
                            X=X_test_samp, feature_name='birthn',\
                            feature_label='# of Births',\
                            color_by='Q1', legend_key=legend_key)

# %%
mldatasets.plot_data_vs_ice(predict_prob_middle_child,\
                            'Probability of Middle Child',\
                            X=X_test_samp, feature_name='birthn',\
                            feature_label='# of Births',\
                            color_by='Q1', legend_key=legend_key)

# %%
mldatasets.plot_data_vs_ice(predict_prob_last_born,\
                            'Probability of Lastborn',\
                            X=X_test_samp, feature_name='birthn',\
                            feature_label='# of Births',\
                            color_by='Q1', legend_key=legend_key)
